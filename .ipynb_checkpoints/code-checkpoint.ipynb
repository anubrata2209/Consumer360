# %%
# Libraries we are using here
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
# RFM & CLV
from lifetimes import BetaGeoFitter
from lifetimes import GammaGammaFitter
from lifetimes.plotting import plot_period_transactions
# Sklearn
from sklearn.preprocessing import MinMaxScaler
import warnings 
warnings.filterwarnings("ignore")
# Display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.float_format", lambda x: '%.3f' % x)

# %%
# Load Dataset
df = pd.read_csv("cleaned_data.csv")

# %%
# First view to the dataset (to see 1st 5 rows )
df.head()
# Out:
#    Invoice StockCode                          Description  Quantity  \
# 0   536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1   536365     71053                  WHITE METAL LANTERN         6
# 2   536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3   536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4   536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  Price  Customer ID           Country
# 0  2024-01-12 08:26:00  2.550        17850  United Kingdom\r
# 1  2024-01-12 08:26:00  3.390        17850  United Kingdom\r
# 2  2024-01-12 08:26:00  2.750        17850  United Kingdom\r
# 3  2024-01-12 08:26:00  3.390        17850  United Kingdom\r
# 4  2024-01-12 08:26:00  3.390        17850  United Kingdom\r

# %%
df.head(10)
# Out:
#    Invoice StockCode                          Description  Quantity  \
# 0   536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1   536365     71053                  WHITE METAL LANTERN         6
# 2   536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3   536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4   536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5   536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6   536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7   536366     22633               HAND WARMER UNION JACK         6
# 8   536366     22632            HAND WARMER RED POLKA DOT         6
# 9   536368     22960             JAM MAKING SET WITH JARS         6
#
#            InvoiceDate  Price  Customer ID           Country
# 0  2024-01-12 08:26:00  2.550        17850  United Kingdom\r
# 1  2024-01-12 08:26:00  3.390        17850  United Kingdom\r
# 2  2024-01-12 08:26:00  2.750        17850  United Kingdom\r
# 3  2024-01-12 08:26:00  3.390        17850  United Kingdom\r
# 4  2024-01-12 08:26:00  3.390        17850  United Kingdom\r
# 5  2024-01-12 08:26:00  7.650        17850  United Kingdom\r
# 6  2024-01-12 08:26:00  4.250        17850  United Kingdom\r
# 7  2024-01-12 08:28:00  1.850        17850  United Kingdom\r
# 8  2024-01-12 08:28:00  1.850        17850  United Kingdom\r
# 9  2024-01-12 08:34:00  4.250        13047  United Kingdom\r

# %%
#for last 5 rows
df.tail()
# Out:
#         Invoice StockCode                      Description  Quantity  \
# 392684   581587     22899      CHILDREN'S APRON DOLLY GIRL         6
# 392685   581587     23254     CHILDRENS CUTLERY DOLLY GIRL         4
# 392686   581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 392687   581587     22138     BAKING SET 9 PIECE RETROSPOT         3
# 392688   581587      POST                          POSTAGE         1
#
#                 InvoiceDate  Price  Customer ID   Country
# 392684  2025-09-12 12:50:00  2.100        12680  France\r
# 392685  2025-09-12 12:50:00  4.150        12680  France\r
# 392686  2025-09-12 12:50:00  4.150        12680  France\r
# 392687  2025-09-12 12:50:00  4.950        12680  France\r
# 392688  2025-09-12 12:50:00 18.000        12680  France\r

# %%
# to see total no.s of columns and rows
df.shape
# Out:
# (392689, 8)

# %%
len(df)
# Out:
# 392689

# %%
#Data Preprocessing
def check_df(dataframe):
    print("------------------- Shape ------------------------")
    print(dataframe.shape)
    print("------------------- Columns ----------------------")
    print(dataframe.columns)
    print("------------------- Types ------------------------")
    print(dataframe.dtypes)
    print("------------------- Head -------------------------")
    print(dataframe.head())
    print("------------------- Tail -------------------------")
    print(dataframe.tail())
    print("------------------- Describe ---------------------")
    print(dataframe.describe().T)

check_df(df)
# Out:
# ------------------- Shape ------------------------
# (392689, 8)
# ------------------- Columns ----------------------
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')
# ------------------- Types ------------------------
# Invoice          int64
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# Price          float64
# Customer ID      int64
# Country         object
# dtype: object
# ------------------- Head -------------------------
#    Invoice StockCode                          Description  Quantity  \
# 0   536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1   536365     71053                  WHITE METAL LANTERN         6
# 2   536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3   536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4   536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  Price  Customer ID           Country
# 0  2024-01-12 08:26:00  2.550        17850  United Kingdom\r
# 1  2024-01-12 08:26:00  3.390        17850  United Kingdom\r
# 2  2024-01-12 08:26:00  2.750        17850  United Kingdom\r
# 3  2024-01-12 08:26:00  3.390        17850  United Kingdom\r
# 4  2024-01-12 08:26:00  3.390        17850  United Kingdom\r
# ------------------- Tail -------------------------
#         Invoice StockCode                      Description  Quantity  \
# 392684   581587     22899      CHILDREN'S APRON DOLLY GIRL         6
# 392685   581587     23254     CHILDRENS CUTLERY DOLLY GIRL         4
# 392686   581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 392687   581587     22138     BAKING SET 9 PIECE RETROSPOT         3
# 392688   581587      POST                          POSTAGE         1
#
#                 InvoiceDate  Price  Customer ID   Country
# 392684  2025-09-12 12:50:00  2.100        12680  France\r
# 392685  2025-09-12 12:50:00  4.150        12680  France\r
# 392686  2025-09-12 12:50:00  4.150        12680  France\r
# 392687  2025-09-12 12:50:00  4.950        12680  France\r
# 392688  2025-09-12 12:50:00 18.000        12680  France\r
# ------------------- Describe ---------------------
#                  count       mean       std        min        25%        50%  \
# Invoice     392689.000 560590.916 13087.133 536365.000 549234.000 561874.000
# Quantity    392689.000     13.120   180.494      1.000      2.000      6.000
# Price       392689.000      3.126    22.242      0.040      1.250      1.950
# Customer ID 392689.000  15287.842  1713.546  12346.000  13955.000  15150.000
#
#                    75%        max
# Invoice     572061.000 581587.000
# Quantity        12.000  80995.000
# Price            3.750   8142.750
# Customer ID  16791.000  18287.000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392689 entries, 0 to 392688
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      392689 non-null  int64
#  1   StockCode    392689 non-null  object
#  2   Description  392689 non-null  object
#  3   Quantity     392689 non-null  int64
#  4   InvoiceDate  392689 non-null  object
#  5   Price        392689 non-null  float64
#  6   Customer ID  392689 non-null  int64
#  7   Country      392689 non-null  object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 24.0+ MB

# %%
# optional: drop invalid rows
df = df.dropna(subset=['InvoiceDate'])
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392689 entries, 0 to 392688
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      392689 non-null  int64
#  1   StockCode    392689 non-null  object
#  2   Description  392689 non-null  object
#  3   Quantity     392689 non-null  int64
#  4   InvoiceDate  392689 non-null  datetime64[ns]
#  5   Price        392689 non-null  float64
#  6   Customer ID  392689 non-null  int64
#  7   Country      392689 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(3)
# memory usage: 24.0+ MB

# %%
#check missing (null) values
df.isnull().sum()
# Out:
# Invoice        0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Invoice        0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# dtype: int64

# %%
# Total number of product in the dataset.
print("the sum of product in the dataset:", df["Description"].count())
# Out:
# the sum of product in the dataset: 392689

# %%
# Total revenue in the dataset
total_price_of_df = ((df["Quantity"] * df["Price"]).sum()).astype(int)
print("The sum of price in the dataset:", total_price_of_df)
# Out:
# The sum of price in the dataset: 8887226

# %%
# Dataset ordered from highest price to lowest price
df.sort_values(by = "Price", ascending  = False).head()
# Out:
#         Invoice StockCode Description  Quantity         InvoiceDate    Price  \
# 116867   551697      POST     POSTAGE         1 2025-03-05 13:46:00 8142.750
# 305360   573077         M      Manual         1 2025-10-27 14:13:00 4161.060
# 305361   573080         M      Manual         1 2025-10-27 14:20:00 4161.060
# 292016   571751         M      Manual         1 2025-10-19 11:18:00 3949.320
# 266722   569382         M      Manual         1 2025-03-10 16:44:00 3155.950
#
#         Customer ID           Country
# 116867        16029  United Kingdom\r
# 305360        12536          France\r
# 305361        12536          France\r
# 292016        12744       Singapore\r
# 266722        15502  United Kingdom\r

# %%
# Dataset ordered from lowest price to highest price
df.sort_values(by = "Price", ascending  = True).head()
# Out:
#         Invoice StockCode                 Description  Quantity  \
# 163422   557639     16045  POPART WOODEN PENCILS ASST       100
# 293015   571904     16045  POPART WOODEN PENCILS ASST       100
# 295207   572092     16045  POPART WOODEN PENCILS ASST       100
# 162390   557492     16045  POPART WOODEN PENCILS ASST       100
# 289238   571496     16045  POPART WOODEN PENCILS ASST       100
#
#                InvoiceDate  Price  Customer ID           Country
# 163422 2025-06-21 16:13:00  0.040        12933  United Kingdom\r
# 293015 2025-10-19 14:41:00  0.040        12522         Germany\r
# 295207 2025-10-20 14:41:00  0.040        17125  United Kingdom\r
# 162390 2025-06-20 15:08:00  0.040        13717  United Kingdom\r
# 289238 2025-10-17 15:02:00  0.040        13265  United Kingdom\r

# %%
#Outlier Observations :Define a safe range for values

# %%
def outlier_thresholds(dataframe, variable):
    quartile1 = dataframe[variable].quantile(0.01)
    quartile3 = dataframe[variable].quantile(0.99)
    interquantile_range = quartile3 - quartile1
    up_limit = quartile3 + 1.5 * interquantile_range
    low_limit = quartile1 - 1.5 * interquantile_range
    return low_limit, up_limit

def replace_with_thresholds(dataframe, variable):
    low_limit, up_limit = outlier_thresholds(dataframe, variable)
    dataframe.loc[(dataframe[variable] < low_limit), variable] = low_limit
    dataframe.loc[(dataframe[variable] > up_limit), variable] = up_limit

replace_with_thresholds(df, "Quantity")  #Fix outliers in Quantity
replace_with_thresholds(df, "Price")     #Fix outliers in Price column

# %%
# Exploratory Data Analysis

# %%
#Categorical Variables

cat_cols = [col for col in df.columns if df[col].dtypes =="O"]
cat_but_car = [col for col in df.columns if df[col].nunique() > 100 and df[col].dtypes == "O"]
cat_cols = [col for col in cat_cols if col not in cat_but_car]
cat_cols
# Out:
# ['Country']

# %%
def cat_summary(dataframe, col_name, plot=False):
    print(pd.DataFrame({col_name: dataframe[col_name].value_counts(),
                        "Ratio": 100 * dataframe[col_name].value_counts() / len(dataframe)}))
    print("-------------------------------------")
    if plot:
        fig_dims = (15, 5)
        fig, ax = plt.subplots(figsize=fig_dims)
        sns.countplot(x=dataframe[col_name], data=dataframe)
        plt.xticks(rotation = 45, ha = 'right')
        plt.show()

cat_summary(df, "Country", plot=True)
# Out:
#                         Country  Ratio
# Country
# United Kingdom\r         349199 88.925
# Germany\r                  9025  2.298
# France\r                   8327  2.121
# EIRE\r                     7226  1.840
# Spain\r                    2479  0.631
# Netherlands\r              2359  0.601
# Belgium\r                  2031  0.517
# Switzerland\r              1841  0.469
# Portugal\r                 1453  0.370
# Australia\r                1181  0.301
# Norway\r                   1071  0.273
# Italy\r                     758  0.193
# Channel Islands\r           747  0.190
# Finland\r                   685  0.174
# Cyprus\r                    603  0.154
# Sweden\r                    450  0.115
# Austria\r                   398  0.101
# Denmark\r                   380  0.097
# Poland\r                    330  0.084
# Japan\r                     321  0.082
# Israel\r                    245  0.062
# Unspecified\r               241  0.061
# Singapore\r                 222  0.057
# Iceland\r                   182  0.046
# USA\r                       179  0.046
# Canada\r                    151  0.038
# Greece\r                    145  0.037
# Malta\r                     112  0.029
# United Arab Emirates\r       68  0.017
# European Community\r         60  0.015
# RSA\r                        57  0.015
# Lebanon\r                    45  0.011
# Lithuania\r                  35  0.009
# Brazil\r                     32  0.008
# Czech Republic\r             25  0.006
# Bahrain\r                    17  0.004
# Saudi Arabia\r                9  0.002
# -------------------------------------

# %%
#Numerical Variables

num_cols = [col for col in df.columns if df[col].dtypes != 'O' and col not in ["Customer ID" , "Invoice"]]
print(num_cols)
# Out:
# ['Quantity', 'InvoiceDate', 'Price']

# %%
def num_summary(dataframe, numerical_col, plot=False):
    quantiles = [0.05, 0.10, 0.20, 0.30, 0.40, 0.50, 0.60, 0.70, 0.80, 0.90, 0.95, 0.99]
    print(dataframe[numerical_col].describe(quantiles).T)

    if plot:
        dataframe[numerical_col].hist(bins=20)
        plt.xlabel(numerical_col)
        plt.title(numerical_col)
        plt.show()

for col in num_cols:
    num_summary(df, col, plot=True)
# Out:
# count   392689.000
# mean        11.950
# std         25.654
# min          1.000
# 5%           1.000
# 10%          1.000
# 20%          2.000
# 30%          2.000
# 40%          4.000
# 50%          6.000
# 60%          8.000
# 70%         12.000
# 80%         12.000
# 90%         24.000
# 95%         36.000
# 99%        120.000
# max        298.500
# Name: Quantity, dtype: float64
# count                           392689
# mean     2025-06-21 08:17:08.748908800
# min                2024-01-12 08:26:00
# 5%                 2024-12-14 15:43:00
# 10%                2025-01-16 16:23:00
# 20%                2025-03-08 13:39:00
# 30%                2025-04-15 14:21:00
# 40%                2025-06-01 13:00:00
# 50%                2025-07-09 08:18:00
# 60%                2025-08-15 14:32:00
# 70%                2025-09-22 18:07:00
# 80%                2025-10-21 14:41:00
# 90%                2025-11-16 17:10:00
# 95%                2025-11-25 12:20:00
# 99%                2025-12-07 14:17:00
# max                2025-12-10 17:19:00
# Name: InvoiceDate, dtype: object
# count   392689.000
# mean         2.900
# std          3.238
# min          0.040
# 5%           0.420
# 10%          0.550
# 20%          0.850
# 30%          1.250
# 40%          1.650
# 50%          1.950
# 60%          2.100
# 70%          2.950
# 80%          4.150
# 90%          6.350
# 95%          8.500
# 99%         14.950
# max         37.060
# Name: Price, dtype: float64

# %%
# unique product
df["StockCode"].nunique()
# Out:
# 3664

# %%
# How many sales for each product?
df_product = df.groupby("Description").agg({"Quantity":"count"})
df_product.reset_index(inplace=True)
df_product
# Out:
#                                Description  Quantity
# 0                   10 COLOUR SPACEBOY PEN       243
# 1               12 COLOURED PARTY BALLOONS       142
# 2                12 DAISY PEGS IN WOOD BOX        66
# 3                12 EGG HOUSE PAINTED WOOD        64
# 4             12 HANGING EGGS HAND PAINTED         8
# 5         12 IVORY ROSE PEG PLACE SETTINGS        92
# 6          12 MESSAGE CARDS WITH ENVELOPES       194
# 7            12 PENCIL SMALL TUBE WOODLAND       286
# 8      12 PENCILS SMALL TUBE RED RETROSPOT       311
# 9              12 PENCILS SMALL TUBE SKULL       299
# 10               12 PENCILS TALL TUBE POSY       173
# 11      12 PENCILS TALL TUBE RED RETROSPOT       243
# 12             12 PENCILS TALL TUBE SKULLS       218
# 13           12 PENCILS TALL TUBE WOODLAND       209
# 14            12 PINK HEN+CHICKS IN BASKET        14
# 15         12 PINK ROSE PEG PLACE SETTINGS        21
# 16          12 RED ROSE PEG PLACE SETTINGS        81
# 17            15 PINK FLUFFY CHICKS IN BOX         7
# 18     15CM CHRISTMAS GLASS BALL 20 LIGHTS       216
# 19         16 PC CUTLERY SET PANTRY DESIGN         1
# 20      16 PIECE CUTLERY SET PANTRY DESIGN        46
# 21      18PC WOODEN CUTLERY SET DISPOSABLE        24
# 22                     2 DAISIES HAIR COMB         1
# 23        2 PICTURE BOOK EGGS EASTER BUNNY        19
# 24       2 PICTURE BOOK EGGS EASTER CHICKS        19
# 25        2 PICTURE BOOK EGGS EASTER DUCKS        16
# 26                 20 DOLLY PEGS RETROSPOT       184
# 27                  200 BENDY SKULL STRAWS        41
# 28            200 RED + WHITE BENDY STRAWS       120
# 29                   3 BIRDS CANVAS SCREEN         2
# 30        3 BLACK CATS W HEARTS BLANK CARD         3
# 31     3 DRAWER ANTIQUE WHITE WOOD CABINET       187
# 32         3 GARDENIA MORRIS BOXED CANDLES        73
# 33      3 HEARTS HANGING DECORATION RUSTIC       262
# 34              3 HOOK HANGER MAGIC GARDEN        95
# 35        3 HOOK PHOTO SHELF ANTIQUE WHITE       304
# 36      3 PIECE SPACEBOY COOKIE CUTTER SET       299
# 37             3 PINK HEN+CHICKS IN BASKET         6
# 38         3 RAFFIA RIBBONS 50'S CHRISTMAS       135
# 39      3 RAFFIA RIBBONS VINTAGE CHRISTMAS        44
# 40             3 ROSE MORRIS BOXED CANDLES       138
# 41                3 STRIPEY MICE FELTCRAFT       406
# 42         3 TIER CAKE TIN GREEN AND CREAM       137
# 43           3 TIER CAKE TIN RED AND CREAM       136
# 44          3 TIER SWEETHEART GARDEN SHELF        43
# 45        3 TRADITIONAL COOKIE CUTTERS SET         4
# 46       3 TRADITIONAl BISCUIT CUTTERS SET       203
# 47       3 WHITE CHOC MORRIS BOXED CANDLES        92
# 48           3 WICK CHRISTMAS BRIAR CANDLE         1
# 49                   36 DOILIES DOLLY GIRL        74
# 50            36 DOILIES VINTAGE CHRISTMAS       160
# 51                36 FOIL HEART CAKE CASES       173
# 52                 36 FOIL STAR CAKE CASES       108
# 53                    36 PENCILS TUBE POSY        11
# 54           36 PENCILS TUBE RED RETROSPOT       230
# 55                  36 PENCILS TUBE SKULLS       182
# 56                36 PENCILS TUBE WOODLAND       143
# 57            3D CHRISTMAS STAMPS STICKERS       106
# 58            3D DOG PICTURE PLAYING CARDS        61
# 59       3D HEARTS HONEYCOMB PAPER GARLAND        34
# 60                3D SHEET OF CAT STICKERS        44
# 61                3D SHEET OF DOG STICKERS        42
# 62       3D TRADITIONAL CHRISTMAS STICKERS       144
# 63           3D VINTAGE CHRISTMAS STICKERS       127
# 64      4 BLUE DINNER CANDLES SILVER FLOCK        29
# 65          4 BURGUNDY WINE DINNER CANDLES        11
# 66     4 IVORY DINNER CANDLES SILVER FLOCK        99
# 67     4 LAVENDER BOTANICAL DINNER CANDLES       103
# 68         4 LILY BOTANICAL DINNER CANDLES        78
# 69         4 PEAR BOTANICAL DINNER CANDLES       108
# 70       4 PINK DINNER CANDLE SILVER FLOCK        30
# 71            4 PINK FLOCK CHRISTMAS BALLS        11
# 72           4 PURPLE FLOCK DINNER CANDLES        37
# 73              4 ROSE PINK DINNER CANDLES        14
# 74               4 SKY BLUE DINNER CANDLES        12
# 75             4 TRADITIONAL SPINNING TOPS       371
# 76             4 VANILLA BOTANICAL CANDLES       122
# 77          4 WILDFLOWER BOTANICAL CANDLES        57
# 78           5 HOOK HANGER MAGIC TOADSTOOL        27
# 79       5 HOOK HANGER RED MAGIC TOADSTOOL       110
# 80           5 STRAND GLASS NECKLACE AMBER         2
# 81        5 STRAND GLASS NECKLACE AMETHYST         1
# 82           5 STRAND GLASS NECKLACE BLACK         3
# 83         5 STRAND GLASS NECKLACE CRYSTAL         9
# 84           50'S CHRISTMAS GIFT BAG LARGE       109
# 85           50'S CHRISTMAS PAPER GIFT BAG        88
# 86          50CM METAL STRING WITH 7 CLIPS        19
# 87         6 CHOCOLATE LOVE HEART T-LIGHTS       114
# 88                6 EGG HOUSE PAINTED WOOD       117
# 89              6 GIFT TAGS 50'S CHRISTMAS       269
# 90           6 GIFT TAGS VINTAGE CHRISTMAS       257
# 91             6 RIBBONS ELEGANT CHRISTMAS       122
# 92                        6 RIBBONS EMPIRE       113
# 93                  6 RIBBONS RUSTIC CHARM       741
# 94              6 RIBBONS SHIMMERING PINKS        76
# 95                       6 ROCKET BALLOONS       160
# 96         60 CAKE CASES DOLLY GIRL DESIGN       359
# 97         60 CAKE CASES VINTAGE CHRISTMAS       479
# 98     60 GOLD AND SILVER FAIRY CAKE CASES         2
# 99             60 TEATIME FAIRY CAKE CASES       672
# 100          6PC WOOD PLATE SET DISPOSABLE        16
# 101                 70'S ALPHABET WALL ART        15
# 102        72 CAKE CASES VINTAGE CHRISTMAS         1
# 103         72 SWEETHEART FAIRY CAKE CASES       515
# 104              75 BLACK PETIT FOUR CASES        17
# 105              75 GREEN FAIRY CAKE CASES        17
# 106              75 GREEN PETIT FOUR CASES        33
# 107                A PRETTY THANK YOU CARD        27
# 108               A4 WALL TIDY BLUE OFFICE         5
# 109               A4 WALL TIDY RED FLOWERS         4
# 110                  ABC TREASURE BOOK BOX       187
# 111                ABSTRACT CIRCLE JOURNAL        28
# 112           ABSTRACT CIRCLES POCKET BOOK        43
# 113            ABSTRACT CIRCLES SKETCHBOOK        61
# 114                 ACRYLIC GEOMETRIC LAMP         9
# 115             ACRYLIC HANGING JEWEL,BLUE        25
# 116             ACRYLIC HANGING JEWEL,PINK         7
# 117               ACRYLIC JEWEL ANGEL,PINK         2
# 118             ACRYLIC JEWEL ICICLE, BLUE         3
# 119             ACRYLIC JEWEL ICICLE, PINK        17
# 120          ACRYLIC JEWEL SNOWFLAKE, PINK         5
# 121           ACRYLIC JEWEL SNOWFLAKE,PINK         1
# 122              ADULT APRON APPLE DELIGHT        40
# 123           ADVENT CALENDAR GINGHAM SACK       166
# 124               AFGHAN SLIPPER SOCK PAIR        19
# 125       AGED GLASS SILVER T-LIGHT HOLDER       283
# 126      AIRLINE BAG VINTAGE JET SET BROWN        96
# 127        AIRLINE BAG VINTAGE JET SET RED       157
# 128      AIRLINE BAG VINTAGE JET SET WHITE        84
# 129           AIRLINE BAG VINTAGE TOKYO 78       249
# 130     AIRLINE BAG VINTAGE WORLD CHAMPION       101
# 131              AIRLINE LOUNGE,METAL SIGN       149
# 132         ALARM CLOCK BAKELIKE CHOCOLATE       325
# 133             ALARM CLOCK BAKELIKE GREEN       797
# 134             ALARM CLOCK BAKELIKE IVORY       470
# 135            ALARM CLOCK BAKELIKE ORANGE       364
# 136              ALARM CLOCK BAKELIKE PINK       619
# 137               ALARM CLOCK BAKELIKE RED       886
# 138          ALPHABET HEARTS STICKER SHEET        38
# 139                 ALPHABET STENCIL CRAFT       165
# 140                        ALUMINIUM HEART         6
# 141                ALUMINIUM STAMPED HEART       126
# 142      AMBER BERTIE GLASS BEAD BAG CHARM         1
# 143     AMBER CHUNKY BEAD BRACELET W STRAP         4
# 144       AMBER CHUNKY GLASS+BEAD NECKLACE         6
# 145         AMBER DIAMANTE EXPANDABLE RING         5
# 146       AMBER DROP EARRINGS W LONG BEADS         5
# 147      AMBER FINE BEAD NECKLACE W TASSEL         2
# 148           AMBER GLASS TASSLE BAG CHARM         2
# 149       AMBER GLASS/SHELL/PEARL NECKLACE         1
# 150            AMBER GLASS/SILVER BRACELET         7
# 151    AMETHYST CHUNKY BEAD BRACELET W STR        11
# 152      AMETHYST DIAMANTE EXPANDABLE RING         3
# 153      AMETHYST HOOP EARRING FLORAL LEAF         3
# 154             ANGEL DECORATION 3 BUTTONS       115
# 155          ANGEL DECORATION PAINTED ZINC        27
# 156        ANGEL DECORATION STARS ON DRESS        91
# 157      ANGEL DECORATION WITH LACE PADDED        11
# 158                        ANIMAL STICKERS        46
# 159            ANIMALS AND NATURE WALL ART        17
# 160      ANT COPPER LIME BOUDICCA BRACELET        15
# 161      ANT COPPER PINK BOUDICCA BRACELET         9
# 162       ANT COPPER RED BOUDICCA BRACELET         6
# 163      ANT COPPER TURQ BOUDICCA BRACELET        12
# 164       ANT SILVER FUSCHIA BOUDICCA RING         7
# 165    ANT SILVER LIME GREEN BOUDICCA RING        10
# 166        ANT SILVER PURPLE BOUDICCA RING         5
# 167     ANT SILVER TURQUOISE BOUDICCA RING         1
# 168            ANT WHITE WIRE HEART SPIRAL        64
# 169          ANTIQUE ALL GLASS CANDLESTICK        82
# 170         ANTIQUE CREAM CUTLERY CUPBOARD        13
# 171            ANTIQUE CREAM CUTLERY SHELF        18
# 172       ANTIQUE GLASS DRESSING TABLE POT       188
# 173         ANTIQUE GLASS HEART DECORATION        28
# 174            ANTIQUE GLASS PEDESTAL BOWL       163
# 175            ANTIQUE GLASS PLACE SETTING         8
# 176               ANTIQUE HEART SHELF UNIT        68
# 177          ANTIQUE IVORY WIRE BOWL SMALL        19
# 178       ANTIQUE MID BLUE FLOWER EARRINGS         2
# 179    ANTIQUE OLIVE GREEN FLOWER EARRINGS         3
# 180     ANTIQUE OPAL WHITE FLOWER EARRINGS         2
# 181      ANTIQUE RASPBERRY FLOWER EARRINGS         1
# 182             ANTIQUE SILVER BAUBLE LAMP        78
# 183           ANTIQUE SILVER T-LIGHT GLASS       537
# 184      ANTIQUE SILVER TEA GLASS ENGRAVED       283
# 185        ANTIQUE SILVER TEA GLASS ETCHED       145
# 186    ANTIQUE TALL SWIRLGLASS TRINKET POT       138
# 187               APOTHECARY MEASURING JAR        21
# 188                      APPLE BATH SPONGE       125
# 189                    APRON APPLE DELIGHT        62
# 190            APRON MODERN VINTAGE COTTON        57
# 191       AQUA BERTIE GLASS BEAD BAG CHARM         3
# 192              AREA PATROLLED METAL SIGN       376
# 193               ARMY CAMO BOOKCOVER TAPE         4
# 194                 ART LIGHTS,FUNK MONKEY        48
# 195                  ASS COL CIRCLE MOBILE         7
# 196       ASS COL LARGE SAND FROG P'WEIGHT         7
# 197      ASS COL SMALL SAND GECKO P'WEIGHT         9
# 198              ASS COLOUR GLOWING TIARAS        25
# 199     ASS DES PHONE SPONGE CRAFT STICKER        16
# 200     ASS FLORAL PRINT MULTI SCREWDRIVER       166
# 201          ASS FLORAL PRINT SPIRIT LEVEL        35
# 202            ASSORTED BOTTLE TOP MAGNETS       134
# 203          ASSORTED CAKES FRIDGE MAGNETS         8
# 204         ASSORTED CHEESE FRIDGE MAGNETS         8
# 205               ASSORTED CIRCULAR MOBILE        20
# 206          ASSORTED COLOUR BIRD ORNAMENT      1395
# 207    ASSORTED COLOUR LIZARD SUCTION HOOK        60
# 208              ASSORTED COLOUR METAL CAT        26
# 209             ASSORTED COLOUR MINI CASES       366
# 210      ASSORTED COLOUR SILK GLASSES CASE         1
# 211       ASSORTED COLOUR SUCTION CUP HOOK        14
# 212         ASSORTED COLOUR T-LIGHT HOLDER        88
# 213        ASSORTED COLOURED CIRCLE MOBILE         8
# 214              ASSORTED COLOURS SILK FAN       325
# 215               ASSORTED CREEPY CRAWLIES        90
# 216      ASSORTED EASTER DECORATIONS BELLS        22
# 217              ASSORTED EASTER GIFT TAGS        58
# 218    ASSORTED FARMYARD ANIMALS IN BUCKET         6
# 219        ASSORTED FLOWER COLOUR \LEIS\""       103
# 220                  ASSORTED INCENSE PACK        27
# 221      ASSORTED LAQUERED INCENSE HOLDERS        13
# 222          ASSORTED MINI MADRAS NOTEBOOK        23
# 223       ASSORTED MONKEY SUCTION CUP HOOK        45
# 224        ASSORTED SANSKRIT MINI NOTEBOOK         6
# 225      ASSORTED SHAPES PHOTO CLIP SILVER        14
# 226         ASSORTED TUTTI FRUTTI BRACELET        68
# 227     ASSORTED TUTTI FRUTTI FOB NOTEBOOK        52
# 228        ASSORTED TUTTI FRUTTI HEART BOX        34
# 229     ASSORTED TUTTI FRUTTI KEYRING BALL        23
# 230      ASSORTED TUTTI FRUTTI LARGE PURSE        24
# 231           ASSORTED TUTTI FRUTTI MIRROR        31
# 232         ASSORTED TUTTI FRUTTI NOTEBOOK        31
# 233              ASSORTED TUTTI FRUTTI PEN        92
# 234      ASSORTED TUTTI FRUTTI SMALL PURSE        31
# 235    ASSTD COL BUTTERFLY/CRYSTAL W/CHIME         9
# 236         ASSTD DESIGN 3D PAPER STICKERS        32
# 237            ASSTD DESIGN RACING CAR PEN        64
# 238     ASSTD FRUIT+FLOWERS FRIDGE MAGNETS        62
# 239          ASSTD MULTICOLOUR CIRCLES MUG        47
# 240                 ASSTD RASTA KEY-CHAINS         3
# 241           BABUSHKA LIGHTS STRING OF 10       116
# 242                      BABY BOOM RIBBONS        88
# 243           BABY MOUSE RED GINGHAM DRESS        21
# 244                BAG 125g SWIRLY MARBLES       247
# 245                BAG 250g SWIRLY MARBLES       198
# 246                BAG 500g SWIRLY MARBLES       112
# 247                   BAG OF SILVER STONES         5
# 248       BAKING MOULD CHOCOLATE CUP CAKES         2
# 249        BAKING MOULD CHOCOLATE CUPCAKES       136
# 250         BAKING MOULD CUPCAKE CHOCOLATE         1
# 251      BAKING MOULD EASTER EGG MILK CHOC        92
# 252     BAKING MOULD EASTER EGG WHITE CHOC        69
# 253      BAKING MOULD HEART MILK CHOCOLATE       146
# 254     BAKING MOULD HEART WHITE CHOCOLATE       111
# 255       BAKING MOULD ROSE MILK CHOCOLATE        52
# 256      BAKING MOULD ROSE WHITE CHOCOLATE        35
# 257      BAKING MOULD TOFFEE CUP CHOCOLATE        64
# 258           BAKING SET 9 PIECE RETROSPOT       858
# 259             BAKING SET SPACEBOY DESIGN       427
# 260      BALLOON ART MAKE YOUR OWN FLOWERS        70
# 261          BALLOON PUMP WITH 10 BALLOONS       112
# 262          BALLOON WATER BOMB PACK OF 35       141
# 263                   BALLOONS WRITING SET       189
# 264             BANK ACCOUNT GREETING CARD        17
# 265                  BANQUET BIRTHDAY CARD       100
# 266       BAROQUE BUTTERFLY EARRINGS BLACK         2
# 267     BAROQUE BUTTERFLY EARRINGS CRYSTAL         1
# 268           BASKET OF FLOWERS SEWING KIT        42
# 269                   BASKET OF TOADSTOOLS        78
# 270               BATH BUILDING BLOCK WORD       243
# 271                          BATHROOM HOOK        22
# 272                    BATHROOM METAL SIGN       446
# 273     BATHROOM SCALES FOOTPRINTS IN SAND        20
# 274           BATHROOM SCALES RUBBER DUCKS        19
# 275        BATHROOM SCALES, TROPICAL BEACH        10
# 276         BATHROOM SET LOVE HEART DESIGN        11
# 277            BEACH HUT DESIGN BLACKBOARD         8
# 278                  BEACH HUT KEY CABINET         9
# 279                       BEACH HUT MIRROR         8
# 280            BEACH HUT SHELF W 3 DRAWERS        20
# 281       BEADED CHANDELIER T-LIGHT HOLDER        34
# 282        BEADED CRYSTAL HEART BLUE LARGE        44
# 283     BEADED CRYSTAL HEART BLUE ON STICK        11
# 284        BEADED CRYSTAL HEART BLUE SMALL        12
# 285       BEADED CRYSTAL HEART GREEN LARGE        50
# 286    BEADED CRYSTAL HEART GREEN ON STICK        13
# 287       BEADED CRYSTAL HEART GREEN SMALL        16
# 288        BEADED CRYSTAL HEART PINK LARGE        52
# 289     BEADED CRYSTAL HEART PINK ON STICK        12
# 290        BEADED CRYSTAL HEART PINK SMALL        34
# 291        BEADED LOVE HEART JEWELLERY SET         1
# 292         BEADED PEARL HEART WHITE LARGE        10
# 293      BEADED PEARL HEART WHITE ON STICK        25
# 294                BELL HEART ANTIQUE GOLD         1
# 295                  BELL HEART DECORATION         9
# 296         BELLE JARDINIERE CUSHION COVER       176
# 297                BEST DAD CANDLE LETTERS         8
# 298           BEWARE OF THE CAT METAL SIGN       365
# 299            BICYCLE PUNCTURE REPAIR KIT       110
# 300                BICYCLE SAFTEY WALL ART        39
# 301            BIG DOUGHNUT FRIDGE MAGNETS        87
# 302                       BIG POLKADOT MUG         1
# 303             BILI NUT AND WOOD NECKLACE         5
# 304                              BINGO SET       280
# 305     BIRD BOX CHRISTMAS TREE DECORATION         5
# 306         BIRD DECORATION GREEN POLKADOT        37
# 307          BIRD DECORATION RED RETROSPOT        57
# 308            BIRD HOUSE HOT WATER BOTTLE       162
# 309           BIRD ON BRANCH CANVAS SCREEN         1
# 310    BIRDCAGE DECORATION TEALIGHT HOLDER        69
# 311      BIRDHOUSE DECORATION MAGIC GARDEN        74
# 312                BIRDHOUSE GARDEN MARKER        76
# 313            BIRDS MOBILE VINTAGE DESIGN        69
# 314                   BIRTHDAY BANNER TAPE         1
# 315             BIRTHDAY BANQUET GIFT WRAP        32
# 316              BIRTHDAY CARD, RETRO SPOT       126
# 317     BIRTHDAY PARTY CORDON BARRIER TAPE        82
# 318             BISCUIT TIN 50'S CHRISTMAS       271
# 319          BISCUIT TIN VINTAGE CHRISTMAS       233
# 320              BISCUIT TIN VINTAGE GREEN       114
# 321               BISCUIT TIN VINTAGE LEAF         3
# 322                BISCUIT TIN VINTAGE RED       146
# 323         BISCUITS SMALL BOWL LIGHT BLUE        79
# 324             BLACK 3 BEAD DROP EARRINGS         1
# 325               BLACK AND WHITE CAT BOWL        43
# 326               BLACK AND WHITE DOG BOWL        48
# 327           BLACK BAROQUE CARRIAGE CLOCK         7
# 328               BLACK BAROQUE WALL CLOCK        14
# 329           BLACK BIRD GARDEN DESIGN MUG        16
# 330        BLACK CANDELABRA T-LIGHT HOLDER        38
# 331                  BLACK CHAMPAGNE GLASS        33
# 332                    BLACK CHERRY LIGHTS         1
# 333          BLACK CHRISTMAS FLOCK DROPLET         1
# 334             BLACK CHRISTMAS TREE 120CM        23
# 335              BLACK CHRISTMAS TREE 60CM        22
# 336     BLACK CHUNKY BEAD BRACELET W STRAP         7
# 337            BLACK CRYSTAL DROP EARRINGS         2
# 338         BLACK DIAMANTE EXPANDABLE RING         5
# 339         BLACK DIAMOND CLUSTER NECKLACE         1
# 340                 BLACK DINER WALL CLOCK        33
# 341            BLACK DROP CRYSTAL NECKLACE         2
# 342       BLACK DROP EARRINGS W LONG BEADS         1
# 343              BLACK EAR MUFF HEADPHONES        18
# 344               BLACK ENAMEL FLOWER RING        10
# 345        BLACK ENCHANTED FOREST PLACEMAT        42
# 346     BLACK FEATHER CHRISTMAS DECORATION         7
# 347      BLACK FINE BEAD NECKLACE W TASSEL         1
# 348              BLACK FLOWER CANDLE PLATE         2
# 349                BLACK GEMSTONE BRACELET         3
# 350           BLACK GEMSTONE NECKLACE 45CM         4
# 351    BLACK GLASS BRACELET W HEART CHARMS         1
# 352        BLACK GRAND BAROQUE PHOTO FRAME         7
# 353                BLACK HEART CARD HOLDER       166
# 354                   BLACK KITCHEN SCALES       183
# 355                 BLACK LOVE BIRD CANDLE        25
# 356         BLACK LOVE BIRD T-LIGHT HOLDER        13
# 357          BLACK MEDIUM GLASS CAKE STAND         8
# 358                BLACK MINI TAPE MEASURE        30
# 359                  BLACK ORANGE SQUEEZER        21
# 360                      BLACK PHOTO ALBUM         3
# 361            BLACK PIRATE TREASURE CHEST        82
# 362               BLACK RECORD COVER FRAME       314
# 363           BLACK SIL'T SQU CANDLE PLATE         2
# 364           BLACK SILOUETTE CANDLE PLATE        20
# 365           BLACK SMALL GLASS CAKE STAND        12
# 366               BLACK SQUARE TABLE CLOCK        12
# 367              BLACK STITCHED WALL CLOCK        29
# 368              BLACK SWEETHEART BRACELET        24
# 369         BLACK TEA TOWEL CLASSIC DESIGN        86
# 370            BLACK TEA,COFFEE,SUGAR JARS        45
# 371    BLACK VINT ART DEC CRYSTAL BRACELET         1
# 372    BLACK VINT ART DEC CRYSTAL NECKLACE         5
# 373         BLACK VINTAGE CRYSTAL EARRINGS         6
# 374                       BLACK WINE GLASS        20
# 375          BLACK+WHITE NECKLACE W TASSEL         5
# 376           BLACK/BLUE POLKADOT UMBRELLA       256
# 377      BLACK/WHITE GLASS/SILVER BRACELET         3
# 378               BLACKCHRISTMAS TREE 30CM         1
# 379                   BLING KEY RING STAND         3
# 380                    BLOND DOLL DOORSTOP        14
# 381           BLOSSOM IMAGES GIFT WRAP SET        93
# 382            BLOSSOM IMAGES NOTEBOOK SET        25
# 383          BLOSSOM IMAGES SCRAP BOOK SET         1
# 384            BLUE & WHITE BREAKFAST TRAY        21
# 385      BLUE 3 PIECE POLKADOT CUTLERY SET        97
# 386              BLUE BIRDHOUSE DECORATION        38
# 387                 BLUE BLOSSOM HAIR CLIP         6
# 388          BLUE BREAKFAST CUP AND SAUCER         3
# 389           BLUE BUNNY EASTER EGG BASKET         3
# 390                  BLUE CALCULATOR RULER        61
# 391     BLUE CAT BISCUIT BARREL PINK HEART         9
# 392    BLUE CHARLIE+LOLA PERSONAL DOORSIGN        92
# 393        BLUE CHECK BAG W HANDLE 34X20CM         5
# 394     BLUE CHENILLE SHAGGY CUSHION COVER        12
# 395        BLUE CIRCLES DESIGN MONKEY DOLL        26
# 396              BLUE CIRCLES DESIGN TEDDY        20
# 397      BLUE CLIMBING HYDRANGA ART FLOWER         3
# 398           BLUE COAT RACK PARIS FASHION       135
# 399            BLUE CRUSOE CHECK LAMPSHADE         3
# 400         BLUE CUSHION COVER WITH FLOWER         9
# 401                      BLUE DAISY MOBILE        12
# 402      BLUE DELPHINIUM ARTIFICIAL FLOWER         6
# 403          BLUE DIAMANTE PEN IN GIFT BOX        21
# 404                  BLUE DINER WALL CLOCK       338
# 405                     BLUE DISCO HANDBAG        10
# 406              BLUE DRAGONFLY HELICOPTER        35
# 407     BLUE DRAWER KNOB ACRYLIC EDWARDIAN       122
# 408        BLUE EASTER EGG HUNT START POST         4
# 409                         BLUE EGG SPOON        71
# 410            BLUE FELT EASTER EGG BASKET        66
# 411    BLUE FELT HANGING HEART WITH FLOWER         1
# 412               BLUE FLOCK CUSHION COVER         2
# 413          BLUE FLOCK GLASS CANDLEHOLDER        10
# 414                  BLUE FLOWER DES PURSE         6
# 415                          BLUE FLY SWAT        42
# 416                       BLUE GEISHA GIRL        10
# 417          BLUE GIANT GARDEN THERMOMETER       163
# 418        BLUE GINGHAM ROSE CUSHION COVER         1
# 419       BLUE GLASS CHUNKY CHARM BRACELET         6
# 420                 BLUE GLASS GEMS IN BAG        19
# 421     BLUE GREEN EMBROIDERY COSMETIC BAG         3
# 422        BLUE HANGING GINGHAM EASTER HEN         5
# 423            BLUE HAPPY BIRTHDAY BUNTING       355
# 424                  BLUE HARMONICA IN BOX       524
# 425              BLUE HEART COMPACT MIRROR        12
# 426                        BLUE HOLE PUNCH         7
# 427           BLUE JUICY FRUIT PHOTO FRAME        29
# 428                  BLUE KNITTED EGG COSY        25
# 429                       BLUE KNITTED HEN        14
# 430      BLUE LEAVES AND BEADS PHONE CHARM         1
# 431               BLUE MONTE CARLO HANDBAG         1
# 432             BLUE MURANO TWIST BRACELET         5
# 433             BLUE MURANO TWIST NECKLACE         3
# 434            BLUE NETTING STORAGE HANGER         7
# 435    BLUE NEW BAROQUE CANDLESTICK CANDLE        28
# 436     BLUE NEW BAROQUE FLOCK CANDLESTICK         1
# 437     BLUE ORGANDY ROUND LAMPSHADE W BEA         4
# 438                      BLUE OWL SOFT TOY       100
# 439                BLUE PADDED SOFT MOBILE         1
# 440            BLUE PAINTED KASHMIRI CHAIR         1
# 441                   BLUE PAISLEY JOURNAL        58
# 442                  BLUE PAISLEY NOTEBOOK        24
# 443               BLUE PAISLEY POCKET BOOK        50
# 444                BLUE PAISLEY SKETCHBOOK        52
# 445                BLUE PAISLEY TISSUE BOX        88
# 446                     BLUE PAPER PARASOL        48
# 447                        BLUE PARTY BAGS       108
# 448            BLUE PATCH PURSE PINK HEART        17
# 449                   BLUE POLKADOT BEAKER        78
# 450                     BLUE POLKADOT BOWL       225
# 451               BLUE POLKADOT COFFEE MUG        62
# 452                      BLUE POLKADOT CUP       217
# 453                  BLUE POLKADOT EGG CUP        44
# 454           BLUE POLKADOT GARDEN PARASOL        51
# 455                 BLUE POLKADOT KIDS BAG        30
# 456              BLUE POLKADOT LUGGAGE TAG        33
# 457           BLUE POLKADOT PASSPORT COVER        35
# 458                    BLUE POLKADOT PLATE       148
# 459             BLUE POLKADOT PUDDING BOWL         8
# 460                    BLUE POLKADOT PURSE         5
# 461        BLUE POLKADOT WASHING UP GLOVES       115
# 462                     BLUE POLKADOT WRAP       215
# 463                  BLUE POT PLANT CANDLE        37
# 464                     BLUE PUDDING SPOON        59
# 465                   BLUE REFECTORY CLOCK        70
# 466          BLUE RETRO KITCHEN WALL CLOCK        17
# 467                BLUE ROSE FABRIC MIRROR        37
# 468    BLUE ROSE PATCH PURSE PINK BUTTERFL         8
# 469              BLUE ROUND COMPACT MIRROR        11
# 470      BLUE SAVANNAH PICNIC HAMPER FOR 2        17
# 471         BLUE SCANDINAVIAN PAISLEY WRAP        39
# 472      BLUE SCOTTIE DOG W FLOWER PATTERN        25
# 473                  BLUE SHARK HELICOPTER         2
# 474          BLUE SPOT CERAMIC DRAWER KNOB       290
# 475             BLUE SQUARE COMPACT MIRROR         8
# 476         BLUE STONES ON WIRE FOR CANDLE        17
# 477        BLUE STRIPE CERAMIC DRAWER KNOB       359
# 478              BLUE STRIPES SHOULDER BAG         3
# 479               BLUE SWEETHEART BRACELET         7
# 480                  BLUE TABLE RUN FLOWER        11
# 481          BLUE TEA TOWEL CLASSIC DESIGN        48
# 482                BLUE TEATIME PRINT BOWL         2
# 483                         BLUE TILE HOOK        16
# 484                        BLUE TILED TRAY         4
# 485              BLUE TRAVEL FIRST AID KIT         7
# 486                     BLUE TV TRAY TABLE        13
# 487         BLUE VICTORIAN FABRIC OVAL BOX        34
# 488               BLUE VINTAGE SPOT BEAKER       164
# 489                   BLUE VOILE LAMPSHADE         9
# 490     BLUE WHITE PLASTIC RINGS LAMPSHADE         5
# 491         BLUE WIRE SPIRAL CANDLE HOLDER         5
# 492        BLUE/CREAM STRIPE CUSHION COVER        99
# 493    BLUE/GREEN SHELL NECKLACE W PENDANT         1
# 494      BLUE/NAT SHELL NECKLACE W PENDANT         1
# 495      BLUE/YELLOW CERAMIC CANDLE HOLDER         1
# 496      BLUE/YELLOW FLOWER DESIGN BIG MUG        12
# 497        BOHEMIAN COLLAGE STATIONERY SET       103
# 498                  BOOM BOX SPEAKER BOYS        56
# 499                 BOOM BOX SPEAKER GIRLS        42
# 500            BOOZE & WOMEN GREETING CARD        33
# 501           BOTANICAL GARDENS WALL CLOCK        80
# 502       BOTANICAL LAVENDER BIRTHDAY CARD        32
# 503           BOTANICAL LAVENDER GIFT WRAP        19
# 504               BOTANICAL LILY GIFT WRAP         7
# 505           BOTANICAL LILY GREETING CARD        31
# 506               BOTANICAL ROSE GIFT WRAP        28
# 507           BOTANICAL ROSE GREETING CARD        21
# 508                   BOTTLE BAG RETROSPOT       105
# 509              BOUDOIR SQUARE TISSUE BOX       149
# 510            BOX OF 24 COCKTAIL PARASOLS       370
# 511     BOX OF 6 ASSORTED COLOUR TEASPOONS        73
# 512    BOX OF 6 CHRISTMAS CAKE DECORATIONS       164
# 513            BOX OF 6 MINI 50'S CRACKERS       373
# 514         BOX OF 6 MINI VINTAGE CRACKERS       335
# 515                BOX OF 9 PEBBLE CANDLES        78
# 516         BOX OF VINTAGE ALPHABET BLOCKS       231
# 517           BOX OF VINTAGE JIGSAW BLOCKS       219
# 518           BOX/12 CHICK & EGG IN BASKET        40
# 519          BOYS ALPHABET IRON ON PATCHES         5
# 520        BOYS VINTAGE TIN SEASIDE BUCKET       137
# 521            BREAD BIN DINER STYLE IVORY       341
# 522             BREAD BIN DINER STYLE MINT       118
# 523             BREAD BIN DINER STYLE PINK       111
# 524              BREAD BIN DINER STYLE RED       249
# 525          BREAD BIN, DINER STYLE, IVORY         1
# 526           BREAD BIN, DINER STYLE, MINT         1
# 527                   BRIGHT BLUES RIBBONS       104
# 528                     BROCADE RING PURSE       208
# 529                     BROCANTE COAT RACK        46
# 530              BROCANTE SHELF WITH HOOKS        69
# 531               BROWN CHECK CAT DOORSTOP        94
# 532      BROWN KUKUI COCONUT SEED NECKLACE         8
# 533            BROWN PIRATE TREASURE CHEST        38
# 534                BUBBLEGUM RING ASSORTED       214
# 535         BUFFALO BILL TREASURE BOOK BOX       137
# 536                  BUFFALO BILL WALL ART        15
# 537                 BULL DOG BOTTLE OPENER       199
# 538         BULL DOG BOTTLE TOP WALL CLOCK        69
# 539    BUNDLE OF 3 ALPHABET EXERCISE BOOKS       318
# 540       BUNDLE OF 3 RETRO EXERCISE BOOKS         5
# 541           BUNDLE OF 3 RETRO NOTE BOOKS       246
# 542      BUNDLE OF 3 SCHOOL EXERCISE BOOKS       180
# 543          BUNNY DECORATION MAGIC GARDEN        59
# 544                          BUNNY EGG BOX        27
# 545                      BUNNY EGG GARLAND        34
# 546         BUNNY WOODEN PAINTED WITH BIRD        93
# 547       BUNNY WOODEN PAINTED WITH FLOWER        64
# 548                       BUNTING , SPOTTY         7
# 549                   BUTTERFLIES STICKERS        51
# 550           BUTTERFLY CROCHET FOOD COVER        50
# 551                BUTTERFLY CUSHION COVER         2
# 552                    BUTTERFLY HAIR BAND         4
# 553                             BUTTON BOX       121
# 554           BUTTONS AND STRIPES NOTEBOOK         7
# 555                           Bank Charges        11
# 556              CABIN BAG VINTAGE PAISLEY        16
# 557            CABIN BAG VINTAGE RETROSPOT        39
# 558                  CACTI T-LIGHT CANDLES       130
# 559               CAKE PLATE LOVEBIRD PINK        43
# 560              CAKE PLATE LOVEBIRD WHITE       149
# 561                CAKE SHOP STICKER SHEET         8
# 562         CAKE STAND 3 TIER MAGIC GARDEN        88
# 563                  CAKE STAND LACE WHITE         1
# 564        CAKE STAND LOVEBIRD 2 TIER PINK        44
# 565       CAKE STAND LOVEBIRD 2 TIER WHITE        74
# 566    CAKE STAND VICTORIAN FILIGREE LARGE         4
# 567      CAKE STAND VICTORIAN FILIGREE MED        17
# 568    CAKE STAND VICTORIAN FILIGREE SMALL        36
# 569         CAKE STAND WHITE TWO TIER LACE        89
# 570               CAKES AND BOWS GIFT TAPE        44
# 571       CAKES AND RABBITS DESIGN FLANNEL        10
# 572           CAKESTAND, 3 TIER, LOVEHEART         1
# 573             CALENDAR FAMILY FAVOURITES        32
# 574              CALENDAR IN SEASON DESIGN        68
# 575              CALENDAR PAPER CUT DESIGN       237
# 576                CAMOUFLAGE DESIGN TEDDY        35
# 577         CAMOUFLAGE EAR MUFF HEADPHONES        17
# 578                   CAMOUFLAGE LED TORCH       120
# 579       CAMPHOR WOOD PORTOBELLO MUSHROOM        23
# 580          CANDLE HOLDER SILVER MADELINE        18
# 581                CANDLE PLATE LACE WHITE        21
# 582        CANDLEHOLDER PINK HANGING HEART       348
# 583         CANDY HEART HANGING DECORATION        42
# 584               CANDY SHOP STICKER SHEET        22
# 585                       CANDY SPOT BUNNY         5
# 586               CANDY SPOT CUSHION COVER         7
# 587             CANDY SPOT EGG WARMER HARE        21
# 588           CANDY SPOT EGG WARMER RABBIT        30
# 589                    CANDY SPOT HAND BAG        21
# 590            CANDY SPOT HEART DECORATION         8
# 591                    CANDY SPOT TEA COSY         2
# 592             CANNABIS LEAF BEAD CURTAIN         2
# 593          CANNISTER VINTAGE LEAF DESIGN         2
# 594                       CAPIZ CHANDELIER         1
# 595              CARAVAN SQUARE TISSUE BOX       127
# 596                    CARD BILLBOARD FONT       332
# 597                   CARD BIRTHDAY COWBOY       155
# 598                      CARD CAT AND TREE       104
# 599                 CARD CHRISTMAS VILLAGE       162
# 600                     CARD CIRCUS PARADE       214
# 601                      CARD DOG AND BALL        87
# 602                        CARD DOLLY GIRL       213
# 603                      CARD GINGHAM ROSE       140
# 604              CARD HOLDER GINGHAM HEART       135
# 605            CARD HOLDER LOVE BIRD LARGE        75
# 606            CARD HOLDER LOVE BIRD SMALL        63
# 607                     CARD I LOVE LONDON       150
# 608                   CARD MOTORBIKE SANTA       177
# 609                       CARD PARTY GAMES        95
# 610                CARD PSYCHEDELIC APPLES       113
# 611                     CARD SUKI BIRTHDAY       126
# 612                       CARD WEDDING DAY        98
# 613      CARDHOLDER GINGHAM CHRISTMAS TREE        63
# 614                CARDHOLDER GINGHAM STAR        58
# 615          CARDHOLDER HOLLY WREATH METAL        91
# 616                      CARNIVAL BRACELET         6
# 617                CAROUSEL DESIGN WASHBAG        26
# 618               CAROUSEL PONIES BABY BIB        13
# 619                               CARRIAGE       133
# 620        CARROT CHARLIE+LOLA COASTER SET        92
# 621              CARTOON PENCIL SHARPENERS        50
# 622             CAST IRON HOOK GARDEN FORK        14
# 623           CAST IRON HOOK GARDEN TROWEL        15
# 624                  CAT AND BIRD WALL ART         4
# 625                 CAT BOWL VINTAGE CREAM       101
# 626         CAT WITH SUNGLASSES BLANK CARD         1
# 627               CD WALL TIDY BLUE OFFICE         2
# 628               CD WALL TIDY RED FLOWERS         5
# 629    CERAMIC BIRDHOUSE CRESTED TIT SMALL        17
# 630    CERAMIC BOWL WITH LOVE HEART DESIGN        57
# 631    CERAMIC BOWL WITH STRAWBERRY DESIGN        84
# 632      CERAMIC CAKE BOWL + HANGING CAKES       100
# 633        CERAMIC CAKE DESIGN SPOTTED MUG       157
# 634      CERAMIC CAKE DESIGN SPOTTED PLATE        76
# 635     CERAMIC CAKE STAND + HANGING CAKES       152
# 636         CERAMIC CHERRY CAKE MONEY BANK       188
# 637    CERAMIC HEART FAIRY CAKE MONEY BANK       234
# 638          CERAMIC LOVE HEART MONEY BANK        36
# 639        CERAMIC PIRATE CHEST MONEY BANK       106
# 640        CERAMIC PLATE STRAWBERRY DESIGN        56
# 641     CERAMIC STRAWBERRY CAKE MONEY BANK       282
# 642          CERAMIC STRAWBERRY DESIGN MUG       146
# 643           CERAMIC STRAWBERRY MONEY BOX        47
# 644        CERAMIC STRAWBERRY TRINKET TRAY        12
# 645           CHALKBOARD KITCHEN ORGANISER         3
# 646                           CHAMBRE HOOK        18
# 647              CHAMPAGNE TRAY BLANK CARD         2
# 648     CHARLIE & LOLA WASTEPAPER BIN BLUE        83
# 649    CHARLIE & LOLA WASTEPAPER BIN FLORA       107
# 650           CHARLIE + LOLA BISCUITS TINS        51
# 651    CHARLIE + LOLA RED HOT WATER BOTTLE       132
# 652         CHARLIE AND LOLA CHARLOTTE BAG         8
# 653          CHARLIE AND LOLA FIGURES TINS       127
# 654            CHARLIE AND LOLA TABLE TINS        60
# 655     CHARLIE LOLA BLUE HOT WATER BOTTLE        37
# 656         CHARLIE+LOLA MY ROOM DOOR SIGN        66
# 657     CHARLIE+LOLA PINK HOT WATER BOTTLE       106
# 658      CHARLIE+LOLA RED HOT WATER BOTTLE        49
# 659    CHARLIE+LOLA\EXTREMELY BUSY\" SIGN"        73
# 660          CHARLOTTE BAG ALPHABET DESIGN        22
# 661            CHARLOTTE BAG APPLES DESIGN       427
# 662        CHARLOTTE BAG DOLLY GIRL DESIGN       347
# 663            CHARLOTTE BAG PINK POLKADOT       494
# 664              CHARLOTTE BAG SUKI DESIGN       590
# 665         CHARLOTTE BAG VINTAGE ALPHABET       325
# 666      CHERRY BLOSSOM CANVAS ART PICTURE         6
# 667        CHERRY BLOSSOM DECORATIVE FLASK       152
# 668             CHERRY BLOSSOM LUGGAGE TAG         6
# 669          CHERRY BLOSSOM PASSPORT COVER        25
# 670                   CHERRY BLOSSOM PURSE         1
# 671             CHERRY BLOSSOM TABLE CLOCK         3
# 672              CHERRY CROCHET FOOD COVER        78
# 673           CHERUB HEART DECORATION GOLD        59
# 674         CHERUB HEART DECORATION SILVER        69
# 675             CHEST 7 DRAWER MA CAMPAGNE        24
# 676          CHEST NATURAL WOOD 20 DRAWERS        13
# 677         CHEST OF DRAWERS GINGHAM HEART        79
# 678            CHICK GREY HOT WATER BOTTLE       288
# 679            CHILDREN'S APRON DOLLY GIRL       261
# 680           CHILDREN'S CIRCUS PARADE MUG       111
# 681                CHILDREN'S SPACEBOY MUG       179
# 682          CHILDRENS APRON APPLES DESIGN       279
# 683        CHILDRENS APRON SPACEBOY DESIGN       451
# 684        CHILDRENS CUTLERY CIRCUS PARADE       143
# 685           CHILDRENS CUTLERY DOLLY GIRL       270
# 686        CHILDRENS CUTLERY POLKADOT BLUE       211
# 687       CHILDRENS CUTLERY POLKADOT GREEN       166
# 688        CHILDRENS CUTLERY POLKADOT PINK       326
# 689        CHILDRENS CUTLERY RETROSPOT RED       232
# 690             CHILDRENS CUTLERY SPACEBOY       320
# 691               CHILDRENS DOLLY GIRL MUG       158
# 692           CHILDRENS GARDEN GLOVES BLUE        66
# 693           CHILDRENS GARDEN GLOVES PINK        52
# 694                 CHILDRENS SPACEBOY MUG         2
# 695      CHILDRENS TOY COOKING UTENSIL SET       124
# 696     CHILDS BREAKFAST SET CIRCUS PARADE       182
# 697        CHILDS BREAKFAST SET DOLLY GIRL       181
# 698          CHILDS BREAKFAST SET SPACEBOY       205
# 699               CHILDS GARDEN BRUSH BLUE        57
# 700               CHILDS GARDEN BRUSH PINK        65
# 701                CHILDS GARDEN FORK BLUE       122
# 702                CHILDS GARDEN FORK PINK       118
# 703                CHILDS GARDEN RAKE BLUE        43
# 704                CHILDS GARDEN RAKE PINK        54
# 705               CHILDS GARDEN SPADE BLUE        75
# 706               CHILDS GARDEN SPADE PINK        63
# 707              CHILDS GARDEN TROWEL BLUE       107
# 708              CHILDS GARDEN TROWEL PINK        95
# 709                          CHILLI LIGHTS       521
# 710          CHINESE DRAGON PAPER LANTERNS        75
# 711          CHOC TRUFFLE GOLD TRINKET POT        49
# 712     CHOCOLATE 1 WICK MORRIS BOX CANDLE        42
# 713     CHOCOLATE 3 WICK MORRIS BOX CANDLE        43
# 714                  CHOCOLATE BOX RIBBONS       237
# 715                   CHOCOLATE CALCULATOR       116
# 716             CHOCOLATE HOT WATER BOTTLE       706
# 717          CHOCOLATE THIS WAY METAL SIGN       379
# 718            CHRISTMAS CARD SCREEN PRINT        43
# 719           CHRISTMAS CARD SINGING ANGEL        25
# 720       CHRISTMAS CARD STACK OF PRESENTS        36
# 721         CHRISTMAS CRAFT HEART STOCKING         1
# 722         CHRISTMAS CRAFT LITTLE FRIENDS       430
# 723         CHRISTMAS CRAFT TREE TOP ANGEL       355
# 724            CHRISTMAS CRAFT WHITE FAIRY       330
# 725             CHRISTMAS DECOUPAGE CANDLE        65
# 726          CHRISTMAS GARLAND STARS,TREES        21
# 727                CHRISTMAS GINGHAM HEART        30
# 728                 CHRISTMAS GINGHAM STAR       140
# 729                 CHRISTMAS GINGHAM TREE       126
# 730      CHRISTMAS HANGING HEART WITH BELL        17
# 731            CHRISTMAS HANGING SNOWFLAKE        44
# 732       CHRISTMAS HANGING STAR WITH BELL       184
# 733       CHRISTMAS HANGING TREE WITH BELL        89
# 734           CHRISTMAS LIGHTS 10 REINDEER       253
# 735             CHRISTMAS LIGHTS 10 SANTAS       131
# 736    CHRISTMAS LIGHTS 10 VINTAGE BAUBLES       159
# 737    CHRISTMAS METAL POSTCARD WITH BELLS        60
# 738          CHRISTMAS METAL TAGS ASSORTED       139
# 739           CHRISTMAS MUSICAL ZINC HEART         5
# 740            CHRISTMAS MUSICAL ZINC STAR        71
# 741            CHRISTMAS MUSICAL ZINC TREE        52
# 742          CHRISTMAS PUDDING TRINKET POT       174
# 743         CHRISTMAS RETROSPOT ANGEL WOOD       152
# 744         CHRISTMAS RETROSPOT HEART WOOD        11
# 745          CHRISTMAS RETROSPOT STAR WOOD       144
# 746          CHRISTMAS RETROSPOT TREE WOOD       130
# 747    CHRISTMAS STAR WISH LIST CHALKBOARD       237
# 748    CHRISTMAS TABLE CANDLE SILVER SPIKE         1
# 749    CHRISTMAS TABLE SILVER CANDLE SPIKE        76
# 750                  CHRISTMAS TOILET ROLL       175
# 751    CHRISTMAS TREE DECORATION WITH BELL        22
# 752            CHRISTMAS TREE HANGING GOLD        66
# 753          CHRISTMAS TREE HANGING SILVER        68
# 754        CHRISTMAS TREE HEART DECORATION        48
# 755            CHRISTMAS TREE PAINTED ZINC        55
# 756         CHRISTMAS TREE STAR DECORATION        49
# 757          CHRISTMAS TREE T-LIGHT HOLDER         8
# 758                  CHRYSANTHEMUM JOURNAL        27
# 759                 CHRYSANTHEMUM NOTEBOOK        36
# 760              CHRYSANTHEMUM POCKET BOOK        20
# 761               CHRYSANTHEMUM SKETCHBOOK        51
# 762    CHUNKY SILVER NECKLACE PASTEL FLOWE        12
# 763               CINAMMON & ORANGE WREATH        33
# 764             CINAMMON SET OF 9 T-LIGHTS       111
# 765                  CINDERELLA CHANDELIER        22
# 766         CINNAMON SCENTED VOTIVE CANDLE        38
# 767            CIRCUS PARADE BABY GIFT SET        89
# 768        CIRCUS PARADE CHILDRENS EGG CUP       113
# 769                CIRCUS PARADE LUNCH BOX       259
# 770            CITRONELLA CANDLE FLOWERPOT       127
# 771           CITRONELLA CANDLE GARDEN POT       126
# 772            CITRUS GARLAND FELT FLOWERS        14
# 773                       CLAM SHELL LARGE         4
# 774                       CLAM SHELL SMALL        30
# 775                  CLASSIC BICYCLE CLIPS        89
# 776           CLASSIC CAFE SUGAR DISPENSER       210
# 777            CLASSIC CHROME BICYCLE BELL       175
# 778             CLASSIC CROME BICYCLE BELL         2
# 779          CLASSIC DIAMANTE EARRINGS JET         1
# 780          CLASSIC DIAMANTE NECKLACE JET         1
# 781      CLASSIC FRENCH STYLE BASKET BROWN        67
# 782      CLASSIC FRENCH STYLE BASKET GREEN        70
# 783    CLASSIC FRENCH STYLE BASKET NATURAL        93
# 784               CLASSIC GLASS COOKIE JAR       249
# 785                CLASSIC GLASS SWEET JAR        14
# 786    CLASSIC METAL BIRDCAGE PLANT HOLDER       261
# 787                CLASSIC SUGAR DISPENSER        12
# 788                    CLASSIC WHITE FRAME        15
# 789             CLASSICAL ROSE CANDLESTAND         7
# 790              CLASSICAL ROSE SMALL VASE        10
# 791              CLASSICAL ROSE TABLE LAMP         2
# 792           CLEAR ACRYLIC FACETED BANGLE         6
# 793         CLEAR CRYSTAL STAR PHONE CHARM         6
# 794    CLEAR DRAWER KNOB ACRYLIC EDWARDIAN       327
# 795         CLEAR LOVE BIRD T-LIGHT HOLDER         6
# 796                  CLEAR MILKSHAKE GLASS         5
# 797               CLEAR STATIONERY BOX SET         2
# 798             CLOCK MAGNET MUM'S KITCHEN        40
# 799         CLOTHES PEGS RETROSPOT PACK 24       642
# 800                      COCKLE SHELL DISH        32
# 801              COCKTAIL SWORDS 50 PIECES        68
# 802               COFFEE MUG APPLES DESIGN       230
# 803         COFFEE MUG BLUE PAISLEY DESIGN        47
# 804           COFFEE MUG CAT + BIRD DESIGN       181
# 805           COFFEE MUG DOG + BALL DESIGN       143
# 806                COFFEE MUG PEARS DESIGN       191
# 807         COFFEE MUG PINK PAISLEY DESIGN        44
# 808             COFFEE SCENT PILLAR CANDLE        45
# 809    COLOUR GLASS T-LIGHT HOLDER HANGING       530
# 810      COLOUR GLASS. STAR T-LIGHT HOLDER       223
# 811     COLOURED GLASS STAR T-LIGHT HOLDER        43
# 812            COLOURFUL FLOWER FRUIT BOWL        11
# 813           COLOURING PENCILS BROWN TUBE       241
# 814             COLUMBIAN CANDLE RECTANGLE        32
# 815                 COLUMBIAN CANDLE ROUND        88
# 816                  COLUMBIAN CUBE CANDLE        20
# 817    CONDIMENT TRAY 4 BOWLS AND 4 SPOONS         9
# 818                CONGRATULATIONS BUNTING         3
# 819              COOK WITH WINE METAL SIGN       607
# 820                  COOKING SET RETROSPOT        25
# 821             COPPER AND BRASS BAG CHARM         2
# 822     COPPER/OLIVE GREEN FLOWER NECKLACE         4
# 823                      CORDIAL GLASS JUG        14
# 824                            CORDIAL JUG         2
# 825                    CORONA MEXICAN TRAY        18
# 826      COSMETIC BAG VINTAGE ROSE PAISLEY        63
# 827            COSY HOUR CIGAR BOX MATCHES       150
# 828           COSY HOUR GIANT TUBE MATCHES        29
# 829         COSY SLIPPER SHOES LARGE GREEN        28
# 830         COSY SLIPPER SHOES SMALL GREEN        48
# 831           COSY SLIPPER SHOES SMALL RED        20
# 832                  COTE D'AZURE NECKLACE         2
# 833             COTTON APRON PANTRY DESIGN       142
# 834      COWBOYS AND INDIANS BIRTHDAY CARD       203
# 835           CRACKED GLAZE EARRINGS BROWN         1
# 836             CRACKED GLAZE EARRINGS RED         1
# 837           CRACKED GLAZE NECKLACE IVORY         2
# 838             CRACKED GLAZE NECKLACE RED         3
# 839           CRAZY DAISY HEART DECORATION        31
# 840            CREAM AND PINK FLOWERS PONY         5
# 841          CREAM BUNNY EASTER EGG BASKET         3
# 842     CREAM CLIMBING HYDRANGA ART FLOWER         3
# 843         CREAM CUPID HEARTS COAT HANGER       243
# 844     CREAM DELPHINIUM ARTIFICIAL FLOWER         8
# 845           CREAM FELT EASTER EGG BASKET       104
# 846     CREAM HANGING HEART T-LIGHT HOLDER         7
# 847                CREAM HEART CARD HOLDER       454
# 848     CREAM SLICE FLANNEL CHOCOLATE SPOT        35
# 849          CREAM SLICE FLANNEL PINK SPOT        63
# 850            CREAM SWEETHEART EGG HOLDER       149
# 851           CREAM SWEETHEART LETTER RACK        23
# 852            CREAM SWEETHEART MINI CHEST       450
# 853          CREAM SWEETHEART WALL CABINET         5
# 854        CREAM WALL PLANTER HEART SHAPED       144
# 855          CROCHET BEAR RED/BLUE KEYRING         4
# 856                    CROCHET DOG KEYRING         1
# 857         CROCHET LILAC/RED BEAR KEYRING         1
# 858        CROCHET ROSE DES CLOTHES HANGER         2
# 859     CROCHET ROSE PURSE WITH SUEDE BACK        17
# 860           CROCHET WHITE RABBIT KEYRING         3
# 861      CRYSTAL CHANDELIER T-LIGHT HOLDER         1
# 862        CRYSTAL CZECH CROSS PHONE CHARM         4
# 863       CRYSTAL DIAMANTE EXPANDABLE RING         8
# 864           CRYSTAL DIAMANTE STAR BROOCH         7
# 865               CRYSTAL FROG PHONE CHARM        11
# 866       CRYSTAL HOOP EARRING FLORAL LEAF         6
# 867         CRYSTAL PAIR HEART HAIR SLIDES         7
# 868          CRYSTAL SEA HORSE PHONE CHARM         8
# 869           CRYSTAL STILETTO PHONE CHARM         2
# 870     CRYSTAL STUD EARRINGS ASSORTED COL        15
# 871    CRYSTAL STUD EARRINGS CLEAR DISPLAY         7
# 872          CUBIC MUG FLOCK BLUE ON BROWN        17
# 873          CUBIC MUG FLOCK PINK ON BROWN        21
# 874                CUBIC MUG PINK POLKADOT        35
# 875          CUPBOARD 3 DRAWER MA CAMPAGNE        87
# 876               CUPCAKE LACE PAPER SET 6       172
# 877           CUPID DESIGN SCENTED CANDLES        30
# 878          CUPID SCENTED CANDLE IN GLASS         4
# 879           CURIO CABINET LINEN AND LACE        18
# 880           CURIOUS IMAGES GIFT WRAP SET        85
# 881            CURIOUS IMAGES NOTEBOOK SET        10
# 882          CURIOUS IMAGES SCRAP BOOK SET         1
# 883          CUSHION COVER PINK UNION JACK        37
# 884       CUT GLASS HEXAGON T-LIGHT HOLDER         9
# 885       CUT GLASS T-LIGHT HOLDER OCTAGON        27
# 886               CUTE BIRD CEATURE SCREEN         2
# 887                         CUTE CATS TAPE        45
# 888             CUTE RABBIT CEATURE SCREEN         2
# 889              DAIRY MAID LARGE MILK JUG       125
# 890                DAIRY MAID PUDDING BOWL         2
# 891                  DAIRY MAID STRIPE MUG        82
# 892                   DAIRY MAID TOASTRACK        84
# 893          DAIRY MAID TRADITIONAL TEAPOT        86
# 894              DAISIES HONEYCOMB GARLAND        51
# 895         DAISY FOLKART HEART DECORATION        17
# 896                    DAISY GARDEN MARKER        54
# 897                        DAISY HAIR BAND         6
# 898                        DAISY HAIR COMB         1
# 899                          DAISY JOURNAL        26
# 900                         DAISY NOTEBOOK        21
# 901                       DAISY SKETCHBOOK        25
# 902            DANISH ROSE BEDSIDE CABINET        10
# 903           DANISH ROSE DECORATIVE PLATE        56
# ...
# 3556     VINTAGE ENAMEL & CRYSTAL EARRINGS         4
# 3557     VINTAGE ENAMEL & CRYSTAL NECKLACE         2
# 3558                VINTAGE ENGRAVED HEART         4
# 3559            VINTAGE GLASS COFFEE CADDY        16
# 3560          VINTAGE GLASS T-LIGHT HOLDER       125
# 3561               VINTAGE GLASS TEA CADDY         3
# 3562     VINTAGE HEADS AND TAILS CARD GAME       489
# 3563            VINTAGE JINGLE BELLS HEART        77
# 3564           VINTAGE JINGLE BELLS WREATH        26
# 3565       VINTAGE KEEPSAKE BOX PARIS DAYS         6
# 3566      VINTAGE KEEPSAKE BOX PINK FLOWER         2
# 3567       VINTAGE KEEPSAKE BOX TRAVELOGUE        10
# 3568                VINTAGE KID DOLLY CARD       145
# 3569          VINTAGE KITCHEN PRINT FRUITS        12
# 3570        VINTAGE KITCHEN PRINT PUDDINGS         7
# 3571         VINTAGE KITCHEN PRINT SEAFOOD         6
# 3572      VINTAGE KITCHEN PRINT VEGETABLES        12
# 3573           VINTAGE LEAF CHOPPING BOARD        41
# 3574         VINTAGE LEAF MAGNETIC NOTEPAD       215
# 3575          VINTAGE NOTEBOOK BEAUTY GIRL         2
# 3576           VINTAGE NOTEBOOK PARIS DAYS         8
# 3577           VINTAGE NOTEBOOK TRAVELOGUE         5
# 3578        VINTAGE PAISLEY STATIONERY SET       205
# 3579        VINTAGE PHOTO ALBUM PARIS DAYS         3
# 3580       VINTAGE PINK DECORATIVE PARASOL         5
# 3581           VINTAGE POST OFFICE CABINET         2
# 3582           VINTAGE RED ENAMEL TRIM JUG       123
# 3583           VINTAGE RED ENAMEL TRIM MUG       101
# 3584         VINTAGE RED ENAMEL TRIM PLATE        67
# 3585           VINTAGE RED KITCHEN CABINET        38
# 3586                       VINTAGE RED MUG        41
# 3587               VINTAGE RED TEATIME MUG        42
# 3588          VINTAGE RED TRIM ENAMEL BOWL        87
# 3589      VINTAGE ROSE BEAD BRACELET BLACK        11
# 3590   VINTAGE ROSE BEAD BRACELET RASPBERR        10
# 3591        VINTAGE SEASIDE JIGSAW PUZZLES        89
# 3592                  VINTAGE SHELLS PRINT        14
# 3593              VINTAGE SNAKES & LADDERS       268
# 3594                    VINTAGE SNAP CARDS       731
# 3595              VINTAGE UNION JACK APRON       114
# 3596            VINTAGE UNION JACK BUNTING       400
# 3597      VINTAGE UNION JACK CUSHION COVER        92
# 3598           VINTAGE UNION JACK DOORSTOP        84
# 3599          VINTAGE UNION JACK MEMOBOARD       205
# 3600            VINTAGE UNION JACK PENNANT        75
# 3601       VINTAGE UNION JACK SHOPPING BAG        41
# 3602              VINTAGE WOODEN BAR STOOL         4
# 3603                  VINTAGE ZINC PLANTER         5
# 3604             VINTAGE ZINC WATERING CAN         7
# 3605       VINTAGE ZINC WATERING CAN SMALL         6
# 3606             VINYL RECORD FRAME SILVER        87
# 3607                     VIP HOLIDAY PURSE         6
# 3608                    VIP PASSPORT COVER        11
# 3609                     VIPPASSPORT COVER        21
# 3610        WAKE UP COCKEREL CALENDAR SIGN        24
# 3611         WAKE UP COCKEREL TILE COASTER        31
# 3612            WAKE UP COCKEREL TILE HOOK        14
# 3613              WALL ART , LOVES' SECRET         2
# 3614           WALL ART , THE MAGIC FOREST         1
# 3615                    WALL ART ,PUDDINGS         2
# 3616                WALL ART 70'S ALPHABET        55
# 3617           WALL ART ANIMALS AND NATURE        26
# 3618               WALL ART BICYCLE SAFETY       121
# 3619               WALL ART BICYCLE SAFTEY         3
# 3620                     WALL ART BIG LOVE        98
# 3621                 WALL ART BUFFALO BILL        29
# 3622                 WALL ART CAT AND BIRD        18
# 3623             WALL ART CLASSIC PUDDINGS       118
# 3624                 WALL ART DOG AND BALL        17
# 3625                  WALL ART DOG LICENCE        63
# 3626                   WALL ART DOLLY GIRL        19
# 3627                 WALL ART GARDEN HAVEN        31
# 3628                 WALL ART HORSE & PONY        34
# 3629                WALL ART I LOVE LONDON        19
# 3630                    WALL ART KEEP CALM        76
# 3631                WALL ART LOVES' SECRET        33
# 3632           WALL ART MID CENTURY MODERN        20
# 3633              WALL ART ONLY ONE PERSON        73
# 3634                     WALL ART SPACEBOY        21
# 3635                 WALL ART STOP FOR TEA       154
# 3636             WALL ART THE MAGIC FOREST         9
# 3637                WALL ART TREASURE AHOY        22
# 3638                 WALL ART VILLAGE SHOW        56
# 3639                WALL ART VINTAGE HEART        27
# 3640           WALL ART WORK REST AND PLAY        26
# 3641              WALL ART,ONLY ONE PERSON         1
# 3642   WALL MIRROR RECTANGLE DIAMANTE PINK        16
# 3643                   WALL TIDY RETROSPOT       104
# 3644         WASH BAG VINTAGE ROSE PAISLEY        62
# 3645                   WASHROOM METAL SIGN       296
# 3646            WATERING CAN BLUE ELEPHANT       277
# 3647            WATERING CAN GARDEN MARKER        70
# 3648           WATERING CAN GREEN DINOSAUR       191
# 3649               WATERING CAN PINK BUNNY       236
# 3650                    WAY OUT METAL SIGN         8
# 3651      WEEKEND BAG VINTAGE ROSE PAISLEY         1
# 3652          WELCOME WOODEN BLOCK LETTERS       167
# 3653              WHEELBARROW FOR CHILDREN        67
# 3654          WHITE 3 FRAME BIRDS AND TREE        10
# 3655        WHITE ALLIUM ARTIFICIAL FLOWER         3
# 3656     WHITE AND BLUE CERAMIC OIL BURNER        15
# 3657       WHITE ANEMONE ARTIFICIAL FLOWER         1
# 3658           WHITE BAMBOO RIBS LAMPSHADE        46
# 3659              WHITE BAROQUE WALL CLOCK        18
# 3660   WHITE BEADED GARLAND STRING 20LIGHT         2
# 3661            WHITE BELL HONEYCOMB PAPER        42
# 3662    WHITE BELL HONEYCOMB PAPER GARLAND        34
# 3663              WHITE BROCANTE SOAP DISH       106
# 3664    WHITE CANDYSTUFT ARTIFICIAL FLOWER        19
# 3665         WHITE CHRISTMAS FLOCK DROPLET         1
# 3666   WHITE CHRISTMAS GARLAND STARS TREES        41
# 3667       WHITE CHRISTMAS STAR DECORATION        29
# 3668             WHITE CHRISTMAS TREE 60CM         2
# 3669       WHITE CHRYSANTHEMUMS ART FLOWER         5
# 3670          WHITE ENAMEL FLOWER HAIR TIE         2
# 3671            WHITE FRANGIPANI HAIR CLIP         1
# 3672             WHITE FRANGIPANI NECKLACE         4
# 3673     WHITE GLASS CHUNKY CHARM BRACELET         8
# 3674    WHITE GOOSE FEATHER CHRISTMAS TREE        50
# 3675         WHITE GOOSE FEATHER TREE 60CM        42
# 3676       WHITE HAND TOWEL WITH BUTTERFLY        14
# 3677     WHITE HANGING BEADS CANDLE HOLDER        48
# 3678    WHITE HANGING HEART T-LIGHT HOLDER      2016
# 3679          WHITE HEART CONFETTI IN TUBE        50
# 3680         WHITE HEART OF GLASS BRACELET         2
# 3681    WHITE HEARTS WIRE PLANT POT HOLDER        59
# 3682         WHITE HONEYCOMB PAPER GARLAND        29
# 3683            WHITE HYDRANGEA ART FLOWER         3
# 3684       WHITE JEWELLED HEART DECORATION       115
# 3685                WHITE LOVEBIRD LANTERN       116
# 3686                   WHITE METAL LANTERN       245
# 3687          WHITE MOROCCAN METAL LANTERN        12
# 3688           WHITE MURANO TWIST BRACELET         2
# 3689      WHITE ROCKING HORSE HAND PAINTED       164
# 3690        WHITE ROSEBUD & PEARL NECKLACE         1
# 3691          WHITE ROSEBUD PEARL BRACELET         7
# 3692          WHITE ROSEBUD PEARL EARRINGS         1
# 3693                    WHITE SAGE INCENSE        25
# 3694          WHITE SKULL HOT WATER BOTTLE       388
# 3695        WHITE SOAP RACK WITH 2 BOTTLES        42
# 3696   WHITE SPOT BLUE CERAMIC DRAWER KNOB       279
# 3697    WHITE SPOT RED CERAMIC DRAWER KNOB       311
# 3698              WHITE SQUARE TABLE CLOCK        11
# 3699          WHITE STITCHED CUSHION COVER        17
# 3700             WHITE STITCHED WALL CLOCK        36
# 3701          WHITE STONE/CRYSTAL EARRINGS         1
# 3702   WHITE TALL PORCELAIN T-LIGHT HOLDER        52
# 3703           WHITE TEA,COFFEE,SUGAR JARS        59
# 3704                     WHITE TISSUE REAM        13
# 3705              WHITE TRAVEL ALARM CLOCK        22
# 3706   WHITE VINT ART DECO CRYSTAL NECKLAC         7
# 3707        WHITE VINTAGE CRYSTAL BRACELET         3
# 3708        WHITE VINTAGE CRYSTAL EARRINGS         3
# 3709                     WHITE WICKER STAR       278
# 3710                 WHITE WIRE EGG HOLDER        66
# 3711           WHITE WIRE PLANT POT HOLDER         2
# 3712           WHITE WITH BLACK CATS PLATE         3
# 3713            WHITE WITH METAL BAG CHARM         1
# 3714        WHITE WOOD GARDEN PLANT LADDER       379
# 3715           WHITE/PINK CHICK DECORATION        18
# 3716    WHITE/PINK CHICK EASTER DECORATION         9
# 3717     WHITE/PINK MINI CRYSTALS NECKLACE         1
# 3718                           WICKER STAR       308
# 3719                   WICKER WREATH LARGE       128
# 3720                   WICKER WREATH SMALL        98
# 3721        WINE BOTTLE DRESSING DARK BLUE         7
# 3722          WINE BOTTLE DRESSING LT.BLUE         4
# 3723                       WIRE EGG BASKET        40
# 3724           WISE MAN STAR SHAPE EGG PAN         6
# 3725    WOOD 2 DRAWER CABINET WHITE FINISH       512
# 3726       WOOD AND GLASS MEDICINE CABINET        10
# 3727     WOOD BLACK BOARD ANT WHITE FINISH       604
# 3728     WOOD S/3 CABINET ANT WHITE FINISH       375
# 3729            WOOD STAMP SET BEST WISHES       148
# 3730                WOOD STAMP SET FLOWERS       131
# 3731         WOOD STAMP SET HAPPY BIRTHDAY       122
# 3732              WOOD STAMP SET THANK YOU       205
# 3733    WOOD STOCKING CHRISTMAS SCANDISPOT       102
# 3734          WOODEN ADVENT CALENDAR CREAM        90
# 3735            WOODEN ADVENT CALENDAR RED       104
# 3736            WOODEN BOX ADVENT CALENDAR         5
# 3737                WOODEN BOX OF DOMINOES       461
# 3738             WOODEN CROQUET GARDEN SET       241
# 3739            WOODEN FRAME ANTIQUE WHITE       816
# 3740         WOODEN HAPPY BIRTHDAY GARLAND       232
# 3741   WOODEN HEART CHRISTMAS SCANDINAVIAN       479
# 3742             WOODEN OWLS LIGHT GARLAND       149
# 3743     WOODEN PICTURE FRAME WHITE FINISH       882
# 3744                WOODEN REGATTA BUNTING        96
# 3745            WOODEN ROUNDERS GARDEN SET       304
# 3746           WOODEN SCHOOL COLOURING SET       404
# 3747            WOODEN SKITTLES GARDEN SET       133
# 3748    WOODEN STAR CHRISTMAS SCANDINAVIAN       451
# 3749    WOODEN TREE CHRISTMAS SCANDINAVIAN       287
# 3750             WOODEN UNION JACK BUNTING       299
# 3751         WOODLAND BUNNIES LOLLY MAKERS        75
# 3752                WOODLAND CHARLOTTE BAG       538
# 3753       WOODLAND DESIGN COTTON TOTE BAG        82
# 3754        WOODLAND HEIGHT CHART STICKERS        79
# 3755        WOODLAND LARGE BLUE FELT HEART         8
# 3756        WOODLAND LARGE PINK FELT HEART        10
# 3757         WOODLAND LARGE RED FELT HEART        18
# 3758                WOODLAND MINI BACKPACK       133
# 3759                WOODLAND MINI RUCKSACK         2
# 3760      WOODLAND PARTY BAG + STICKER SET       143
# 3761        WOODLAND SMALL BLUE FELT HEART        28
# 3762        WOODLAND SMALL PINK FELT HEART        26
# 3763         WOODLAND SMALL RED FELT HEART        43
# 3764                     WOODLAND STICKERS        53
# 3765            WOODLAND STORAGE BOX LARGE        22
# 3766            WOODLAND STORAGE BOX SMALL        18
# 3767     WORLD WAR 2 GLIDERS ASSTD DESIGNS       472
# 3768           WOVEN BERRIES CUSHION COVER         7
# 3769        WOVEN BUBBLE GUM CUSHION COVER         6
# 3770             WOVEN CANDY CUSHION COVER         5
# 3771             WOVEN FROST CUSHION COVER         6
# 3772       WOVEN ROSE GARDEN CUSHION COVER         8
# 3773            WOVEN SUNSET CUSHION COVER         3
# 3774                   WRAP 50'S CHRISTMAS       150
# 3775               WRAP A PRETTY THANK YOU         2
# 3776                  WRAP ALPHABET DESIGN       232
# 3777                  WRAP ALPHABET POSTER        63
# 3778                     WRAP BAD HAIR DAY        22
# 3779           WRAP BILLBOARD FONTS DESIGN        62
# 3780                      WRAP BIRD GARDEN        51
# 3781             WRAP BLUE RUSSIAN FOLKART         1
# 3782                         WRAP CAROUSEL        14
# 3783           WRAP CHRISTMAS SCREEN PRINT        31
# 3784                WRAP CHRISTMAS VILLAGE       140
# 3785                    WRAP CIRCUS PARADE       100
# 3786                          WRAP COWBOYS        69
# 3787                     WRAP DAISY CARPET        26
# 3788                    WRAP DOILEY DESIGN       162
# 3789                       WRAP DOLLY GIRL        99
# 3790                     WRAP ENGLISH ROSE       248
# 3791                      WRAP FLOWER SHOP        62
# 3792                         WRAP FOLK ART         8
# 3793                     WRAP GINGHAM ROSE        82
# 3794                      WRAP GREEN PEARS        74
# 3795            WRAP GREEN RUSSIAN FOLKART         2
# 3796                    WRAP I LOVE LONDON       100
# 3797               WRAP KEEP CALM BIRTHDAY        36
# 3798                     WRAP MAGIC FOREST        43
# 3799                      WRAP MONSTER FUN        47
# 3800                     WRAP PAISLEY PARK       120
# 3801                 WRAP PINK FAIRY CAKES       167
# 3802                       WRAP PINK FLOCK         1
# 3803                   WRAP POPPIES DESIGN       159
# 3804                       WRAP RED APPLES       173
# 3805                       WRAP RED DOILEY        15
# 3806                WRAP RED VINTAGE DOILY        69
# 3807                 WRAP SUKI AND FRIENDS       134
# 3808               WRAP SUMMER ROSE DESIGN         4
# 3809                   WRAP VINTAGE DOILEY         2
# 3810                    WRAP VINTAGE DOILY        93
# 3811              WRAP VINTAGE LEAF DESIGN       135
# 3812            WRAP VINTAGE PETALS DESIGN       104
# 3813                      WRAP WEDDING DAY        39
# 3814          WRAP, BILLBOARD FONTS DESIGN        34
# 3815                        WRAP, CAROUSEL         4
# 3816       YELLOW BREAKFAST CUP AND SAUCER        14
# 3817        YELLOW COAT RACK PARIS FASHION        91
# 3818           YELLOW DRAGONFLY HELICOPTER         6
# 3819     YELLOW EASTER EGG HUNT START POST        18
# 3820    YELLOW FELT HANGING HEART W FLOWER         3
# 3821       YELLOW FLOWERS FELT HANDBAG KIT        18
# 3822       YELLOW GIANT GARDEN THERMOMETER        88
# 3823            YELLOW METAL CHICKEN HEART        61
# 3824    YELLOW PINK FLOWER DESIGN BIG BOWL         3
# 3825               YELLOW POT PLANT CANDLE         9
# 3826               YELLOW SHARK HELICOPTER        38
# 3827               YELLOW/BLUE RETRO RADIO         8
# 3828     YELLOW/ORANGE FLOWER DESIGN PLATE         2
# 3829     YELLOW/PINK FLOWER DESIGN BIG MUG        15
# 3830        YOU'RE CONFUSING ME METAL SIGN       348
# 3831         YULETIDE IMAGES GIFT WRAP SET        59
# 3832       YULETIDE IMAGES S/6 PAPER BOXES         7
# 3833                    ZINC BOX SIGN HOME        62
# 3834         ZINC FINISH 15CM PLANTER POTS        49
# 3835             ZINC FOLKART SLEIGH BELLS       344
# 3836      ZINC HEART FLOWER T-LIGHT HOLDER        57
# 3837     ZINC HEART LATTICE 2 WALL PLANTER        11
# 3838      ZINC HEART LATTICE CHARGER LARGE        14
# 3839      ZINC HEART LATTICE CHARGER SMALL         8
# 3840     ZINC HEART LATTICE T-LIGHT HOLDER        63
# 3841          ZINC HEART LATTICE TRAY OVAL         7
# 3842             ZINC HEART T-LIGHT HOLDER        49
# 3843          ZINC HEARTS PLANT POT HOLDER        49
# 3844            ZINC HERB GARDEN CONTAINER       188
# 3845           ZINC METAL HEART DECORATION       486
# 3846                 ZINC PLANT POT HOLDER         1
# 3847              ZINC STAR T-LIGHT HOLDER        36
# 3848             ZINC SWEETHEART SOAP DISH        19
# 3849      ZINC SWEETHEART WIRE LETTER RACK        78
# 3850        ZINC T-LIGHT HOLDER STAR LARGE       149
# 3851       ZINC T-LIGHT HOLDER STARS LARGE         2
# 3852       ZINC T-LIGHT HOLDER STARS SMALL       238
# 3853          ZINC TOP 2 DOOR WOODEN SHELF         9
# 3854       ZINC WILLIE WINKIE CANDLE STICK       191
# 3855           ZINC WIRE KITCHEN ORGANISER        12
# 3856      ZINC WIRE SWEETHEART LETTER TRAY        20

# %%
# Top 10 Products by quantity
top_pr= df_product.sort_values(by="Quantity",ascending=False).head(10)

sns.barplot(x="Description", y="Quantity", data=top_pr)
plt.xticks(rotation=90)
plt.show()

# %%
# Calculating total price per invoice and adding it.
df["TotalPrice"] = df["Price"] * df["Quantity"]

# %%
df.head()
# Out:
#    Invoice StockCode                          Description  Quantity  \
# 0   536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1   536365     71053                  WHITE METAL LANTERN     6.000
# 2   536365    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3   536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4   536365    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
#
#           InvoiceDate  Price  Customer ID           Country  TotalPrice
# 0 2024-01-12 08:26:00  2.550        17850  United Kingdom\r      15.300
# 1 2024-01-12 08:26:00  3.390        17850  United Kingdom\r      20.340
# 2 2024-01-12 08:26:00  2.750        17850  United Kingdom\r      22.000
# 3 2024-01-12 08:26:00  3.390        17850  United Kingdom\r      20.340
# 4 2024-01-12 08:26:00  3.390        17850  United Kingdom\r      20.340

# %%
#Customer Segmentation With RFM

'''The RFM model is based on three quantitative factors:
1. Recency: How recently a customer has made a purchase
2. Frequency: How often a customer makes a purchase
3. Monetary value: How much money a customer spends on purchases '''
# Out:
# 'The RFM model is based on three quantitative factors:\n1. Recency: How recently a customer has made a purchase\n2. Frequency: How often a customer makes a purchase\n3. Monetary value: How much money a customer spends on purchases '

# %%
# Preparation of RFM Metrics
''' recency: the difference between today and the customer's last purchase date, in days
    frequency: customer's shopping frequency
    monetary: total money paid by the customer '''
# Out:
# " recency: the difference between today and the customer's last purchase date, in days\n    frequency: customer's shopping frequency\n    monetary: total money paid by the customer "

# %%
# Determining the analysis date for the recency
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])

# %%
# The final date in the dataset is used as the reference date (‘today’) for recency calculations.
df["InvoiceDate"].max()
# Out:
# Timestamp('2025-12-10 17:19:00')

# %%
#This value is used to compute recency values.
today_date = dt.datetime(2025, 12, 11)

# %%
# Generating RFM metrics
rfm = df.groupby("Customer ID").agg({"InvoiceDate": lambda InvıiceDate: (today_date- InvıiceDate.max()).days, #Recency Calculation
                                    "Invoice": lambda Invoice: Invoice.nunique(),                             #Frequency Calculation
                                    "TotalPrice": lambda TotalPrice: TotalPrice.sum()})                       #Monetary Calculation

rfm.columns = ["recency","frequency","monetary"]
rfm.describe().T
# Out:
#              count     mean      std   min     25%     50%      75%        max
# recency   4338.000  105.511  115.130 0.000  22.000  61.000  161.750    698.000
# frequency 4338.000    4.272    7.698 1.000   1.000   2.000    5.000    209.000
# monetary  4338.000 1886.657 7701.957 3.750 302.125 657.265 1625.530 266163.525

# %%
#Generating RFM Scores

# %%
# recency_score
rfm["recency_score"] = pd.qcut(rfm['recency'], 5, labels=[5, 4, 3, 2, 1])
# frequency_score
rfm["frequency_score"] = pd.qcut(rfm["frequency"].rank(method="first"), 5, labels=[1, 2, 3, 4, 5])
# monetary_score
rfm["monetary_score"] = pd.qcut(rfm["monetary"], 5, labels=[1, 2, 3, 4, 5])

#  RFM Score
rfm["RFM_SCORE"] = (rfm["recency_score"].astype(str) + rfm["frequency_score"].astype(str))
rfm.head(10)
# Out:
#              recency  frequency  monetary recency_score frequency_score  \
# Customer ID
# 12346            326          1   310.440             1               1
# 12347             40          7  4310.000             4               5
# 12348             76          4  1770.780             3               4
# 12349             19          1  1491.720             4               1
# 12350            311          1   331.460             1               1
# 12352             73          8  1756.340             3               5
# 12353            205          1    89.000             1               1
# 12354            233          1  1079.400             1               1
# 12355             96          1   459.400             2               1
# 12356             23          3  2811.430             4               3
#
#             monetary_score RFM_SCORE
# Customer ID
# 12346                    2        11
# 12347                    5        45
# 12348                    4        34
# 12349                    4        41
# 12350                    2        11
# 12352                    4        35
# 12353                    1        11
# 12354                    4        11
# 12355                    2        21
# 12356                    5        43

# %%
#Segmenting Customers Based on RFM Scores

# %%
seg_map = {
    r'[1-2][1-2]': 'lost',                
    r'[1-2][3-4]': 'hibernating',
    r'[1-2]5': 'cant_lose_them',
    r'3[1-2]': 'about_to_sleep',
    r'33': 'needs_attention',
    r'[3-4][4-5]': 'loyal_customers',
    r'41': 'promising',
    r'51': 'recent_users',
    r'[4-5][2-3]': 'potential_loyalists',
    r'5[4-5]': 'champions'
}

rfm['segment'] = rfm['RFM_SCORE'].replace(seg_map, regex=True)

# %%
rfm.head(10)
# Out:
#              recency  frequency  monetary recency_score frequency_score  \
# Customer ID
# 12346            326          1   310.440             1               1
# 12347             40          7  4310.000             4               5
# 12348             76          4  1770.780             3               4
# 12349             19          1  1491.720             4               1
# 12350            311          1   331.460             1               1
# 12352             73          8  1756.340             3               5
# 12353            205          1    89.000             1               1
# 12354            233          1  1079.400             1               1
# 12355             96          1   459.400             2               1
# 12356             23          3  2811.430             4               3
#
#             monetary_score RFM_SCORE              segment
# Customer ID
# 12346                    2        11                 lost
# 12347                    5        45      loyal_customers
# 12348                    4        34      loyal_customers
# 12349                    4        41            promising
# 12350                    2        11                 lost
# 12352                    4        35      loyal_customers
# 12353                    1        11                 lost
# 12354                    4        11                 lost
# 12355                    2        21                 lost
# 12356                    5        43  potential_loyalists

# %%
# Summarize customer behavior for each segment using averages and counts
rfm[["segment", "recency", "frequency", "monetary"]].groupby("segment").agg(["mean", "count"])
# Out:
#                     recency       frequency       monetary
#                        mean count      mean count     mean count
# segment
# about_to_sleep       64.074   339     1.147   339  492.371   339
# cant_lose_them      134.221    68     8.235    68 3205.351    68
# champions             9.301   665    11.714   665 5955.993   665
# hibernating         171.645   589     2.832   589  878.590   589
# lost                244.040  1069     1.099  1069  375.375  1069
# loyal_customers      42.131   786     6.822   786 2988.864   786
# needs_attention      63.878   196     2.388   196  883.068   196
# potential_loyalists  20.343   478     2.033   478  731.517   478
# promising            28.708    96     1.000    96  317.718    96
# recent_users         11.154    52     1.000    52  335.445    52

# %%
#Visualization of RFM Segments

# %%
sgm= rfm["segment"].value_counts() #Count customers in each segment
plt.figure(figsize=(10,7))          
sns.barplot(x=sgm.index,y=sgm.values)
plt.xticks(rotation=45)      #Makes labels readable by rotating (for long names)
plt.title('Customer Segments',color = 'purple',fontsize=15)
plt.show()

# %%
labels = rfm["segment"].value_counts().index
colors = ['blue','yellow','orange','purple','green','red']
sizes = rfm["segment"].value_counts().values


# visual
plt.figure(figsize = (7,7))
plt.pie(sizes, explode=None, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('Customer Segments',color = 'blue',fontsize = 15)
plt.show()

# %%
sgm = rfm["segment"].value_counts()

sgm_dict = {k.replace("_", " ").title(): v for k, v in sgm.items()}

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

fig, ax = plt.subplots(figsize=(10, 8))

#  total customers
total = sum(sgm_dict.values())

def add_box(x, y, w, h, color, label):
    count = sgm_dict.get(label, 0)
    percent = (count / total) * 100 if total > 0 else 0
    
    text = f"{label}\n{count} ({percent:.1f}%)"
    
    ax.add_patch(Rectangle((x, y), w, h, facecolor=color, edgecolor='white'))
    ax.text(x + w/2, y + h/2, text, ha='center', va='center', fontsize=10)

# --- TOP ROW ---
add_box(0, 6, 4, 2, '#CD6155', "Cant Lose Them")
add_box(4, 4, 4, 4, '#808B96', "Loyal Customers")
add_box(8, 4, 2, 4, '#5DADE2', "Champions")

# --- MIDDLE ---
add_box(0, 3, 4, 3, '#F8C471', "Hibernating")
add_box(4, 3, 2, 1, '#F5CBA7', "Needs Attention")
add_box(6, 2, 4, 3, '#48C9B0', "Potential Loyalists")

# --- LOWER ---
add_box(0, 0, 4, 3, '#BDC3C7', "Lost")
add_box(4, 0, 2, 3, '#A3E4D7', "About To Sleep")
add_box(6, 0, 2, 2, '#D5CBAF', "Promising")
add_box(8, 2, 2, 2, '#ABEBC6', "Recent Users")
add_box(8, 0, 2, 2, '#BB8FCE', "Price Sensitive")

# Axis settings
ax.set_xlim(0, 10)
ax.set_ylim(0, 8)

ax.set_xlabel("Recency score", fontsize=12)
ax.set_ylabel("Frequency & Monetary score", fontsize=12)

plt.title("Predictive Segments (RFM)", fontsize=18)
plt.axis('off')

plt.show()

# %%
# Treemap Visualization
df_treemap = rfm.groupby('segment').agg('count').reset_index()
df_treemap.head(10)
# Out:
#                segment  recency  frequency  monetary  recency_score  \
# 0       about_to_sleep      339        339       339            339
# 1       cant_lose_them       68         68        68             68
# 2            champions      665        665       665            665
# 3          hibernating      589        589       589            589
# 4                 lost     1069       1069      1069           1069
# 5      loyal_customers      786        786       786            786
# 6      needs_attention      196        196       196            196
# 7  potential_loyalists      478        478       478            478
# 8            promising       96         96        96             96
# 9         recent_users       52         52        52             52
#
#    frequency_score  monetary_score  RFM_SCORE
# 0              339             339        339
# 1               68              68         68
# 2              665             665        665
# 3              589             589        589
# 4             1069            1069       1069
# 5              786             786        786
# 6              196             196        196
# 7              478             478        478
# 8               96              96         96
# 9               52              52         52

# %%
print("----------------- RFM segmentation complete.------------------------")
# Out:
# ----------------- RFM segmentation complete.------------------------

# %%
# top spending customers

# %%
print("Columns in rfm:", rfm.columns.tolist())
print("Shape:", rfm.shape)
print(rfm.head(3))
# Out:
# Columns in rfm: ['recency', 'frequency', 'monetary', 'recency_score', 'frequency_score', 'monetary_score', 'RFM_SCORE', 'segment']
# Shape: (4338, 8)
#              recency  frequency  monetary recency_score frequency_score  \
# Customer ID
# 12346            326          1   310.440             1               1
# 12347             40          7  4310.000             4               5
# 12348             76          4  1770.780             3               4
#
#             monetary_score RFM_SCORE          segment
# Customer ID
# 12346                    2        11             lost
# 12347                    5        45  loyal_customers
# 12348                    4        34  loyal_customers

# %%
rfm['r_score'] = rfm['recency_score']
rfm['f_score'] = rfm['frequency_score']
rfm['m_score'] = rfm['monetary_score']

rfm['segment'] = rfm['segment'].str.lower().str.replace(' ', '_')

# %%
rfm['spend_rank'] = rfm['monetary'].rank(pct=True)
top_spenders = rfm[rfm['spend_rank'] >= 0.80]
overlap      = top_spenders[top_spenders['segment'] == 'champions']
pct          = len(overlap) / len(top_spenders) * 100

print(f"Total customers    : {len(rfm):,}")
print(f"Top 20% spenders   : {len(top_spenders):,}")
print(f"Of those, Champions: {len(overlap):,}  ({pct:.1f}%)")

print("\n=== Top 10 spenders and their segments ===")
print(rfm.nlargest(10, 'monetary')
         [['recency_score','frequency_score','monetary_score','monetary','segment']]
         .to_string())

print("\n=== Segment distribution in top 20% spenders ===")
print(top_spenders['segment'].value_counts())
# Out:
# Total customers    : 4,338
# Top 20% spenders   : 868
# Of those, Champions: 376  (43.3%)
#
# === Top 10 spenders and their segments ===
#             recency_score frequency_score monetary_score   monetary          segment
# Customer ID
# 14646                   5               5              5 266163.525        champions
# 18102                   5               5              5 231584.345        champions
# 14911                   5               5              5 138919.840        champions
# 17450                   5               5              5 131550.645        champions
# 12415                   4               5              5 120210.355  loyal_customers
# 14156                   5               5              5 115551.920        champions
# 17511                   5               5              5  90952.235        champions
# 13694                   4               5              5  63785.025  loyal_customers
# 16684                   5               5              5  61879.135        champions
# 15311                   5               5              5  60632.750        champions
#
# === Segment distribution in top 20% spenders ===
# segment
# champions              376
# loyal_customers        345
# hibernating             49
# cant_lose_them          43
# potential_loyalists     21
# lost                    14
# needs_attention         13
# about_to_sleep           7
# Name: count, dtype: int64

# %%
# -------------------------------- Cohort Analysis -----------------------------------------------------

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392689 entries, 0 to 392688
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      392689 non-null  int64
#  1   StockCode    392689 non-null  object
#  2   Description  392689 non-null  object
#  3   Quantity     392689 non-null  float64
#  4   InvoiceDate  392689 non-null  datetime64[ns]
#  5   Price        392689 non-null  float64
#  6   Customer ID  392689 non-null  int64
#  7   Country      392689 non-null  object
#  8   TotalPrice   392689 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(3)
# memory usage: 27.0+ MB

# %%
# Assign cohort month
df['cohort_month'] = (df.groupby('Customer ID')['InvoiceDate']
                        .transform('min')
                        .dt.to_period('M'))
df['invoice_period'] = df['InvoiceDate'].dt.to_period('M')
df['period_number'] = (df['invoice_period'] - df['cohort_month']).apply(lambda x: x.n)

# %%
# Build retention matrix
cohort_data = (df.groupby(['cohort_month', 'period_number'])['Customer ID']
                 .nunique()
                 .reset_index()
                 .rename(columns={'Customer ID': 'customers'}))

cohort_pivot = cohort_data.pivot(
    index='cohort_month', columns='period_number', values='customers'
)
cohort_size  = cohort_pivot.iloc[:, 0]
retention    = cohort_pivot.divide(cohort_size, axis=0).round(3) * 100

# %%
#Heatmap
fig, ax = plt.subplots(figsize=(14, max(5, len(retention) * 0.7)))
sns.heatmap(
    retention, annot=True, fmt='.1f',
    cmap='YlOrRd_r', linewidths=0.5,
    cbar_kws={'label': 'Retention Rate (%)'},
    ax=ax
)
ax.set_title('Cohort Retention Matrix (%) – Consumer360', fontsize=14)
ax.set_xlabel('Months Since First Purchase')
ax.set_ylabel('Cohort Month')
plt.tight_layout()
plt.savefig('cohort_retention.png', dpi=150)
plt.show()
print(" Cohort analysis complete.")
# Out:
#  Cohort analysis complete.

# %%
 # --------------------      Market Basket Analysis (mlxtend Apriori)       ----------------------------------

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392689 entries, 0 to 392688
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Invoice         392689 non-null  int64
#  1   StockCode       392689 non-null  object
#  2   Description     392689 non-null  object
#  3   Quantity        392689 non-null  float64
#  4   InvoiceDate     392689 non-null  datetime64[ns]
#  5   Price           392689 non-null  float64
#  6   Customer ID     392689 non-null  int64
#  7   Country         392689 non-null  object
#  8   TotalPrice      392689 non-null  float64
#  9   cohort_month    392689 non-null  period[M]
#  10  invoice_period  392689 non-null  period[M]
#  11  period_number   392689 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(3), period[M](2)
# memory usage: 36.0+ MB

# %%
import mlxtend
print(mlxtend.__version__)
# Out:
# 0.23.4

# %%
# Market Basket
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
# Filter top 100 products
top_products = df['Description'].value_counts().head(100).index
df_filtered = df[df['Description'].isin(top_products)]

# Build basket
basket = (df_filtered.groupby(['Invoice', 'Description'])['Quantity']
            .sum()
            .unstack(fill_value=0))

# Convert to boolean
basket_bin = (basket > 0)

# Use FP-Growth (best)
from mlxtend.frequent_patterns import fpgrowth

freq_items = fpgrowth(
    basket_bin,
    min_support=0.05,
    use_colnames=True
)

print(freq_items.head())
# Out:
#    support                              itemsets
# 0    0.131  (WHITE HANGING HEART T-LIGHT HOLDER)
# 1    0.091       (ASSORTED COLOUR BIRD ORNAMENT)
# 2    0.058            (JAM MAKING SET WITH JARS)
# 3    0.073                             (POSTAGE)
# 4    0.058            (ALARM CLOCK BAKELIKE RED)

# %%
# Increasing combinations:
from mlxtend.frequent_patterns import fpgrowth

freq_items = fpgrowth(
    basket_bin,
    min_support=0.03,   # slightly lower
    use_colnames=True,
    max_len=2           # allow pairs
)

# %%
# Association Rules 
from mlxtend.frequent_patterns import association_rules
if len(freq_items) > 0:
    rules = association_rules(freq_items,
                              metric='lift',
                              min_threshold=1.0)
    rules = rules.sort_values('lift', ascending=False)

    print(f"\n── Top 10 Association Rules (by Lift) ──")
    print(rules[['antecedents','consequents',
                 'support','confidence','lift']]
          .head(10)
          .to_string(index=False))

    # Scatter: Support vs Confidence ───────────────────
    fig, ax = plt.subplots(figsize=(10, 6))
    scatter = ax.scatter(
        rules['support'], rules['confidence'],
        c=rules['lift'], cmap='plasma',
        s=rules['lift']*30, alpha=0.7, edgecolors='white', linewidth=0.5
    )
    plt.colorbar(scatter, ax=ax, label='Lift')
    ax.set_xlabel('Support');  ax.set_ylabel('Confidence')
    ax.set_title('Association Rules: Support vs Confidence (size=Lift)', fontsize=13)
    plt.tight_layout();  plt.savefig('market_basket_rules.png', dpi=150);  plt.show()

    # Top product pairs table ───────────────────────────
    rules['antecedents_str'] = rules['antecedents'].apply(
        lambda x: ', '.join(list(x)))
    rules['consequents_str'] = rules['consequents'].apply(
        lambda x: ', '.join(list(x)))
    top_rules_df = rules[['antecedents_str','consequents_str',
                           'support','confidence','lift']].head(20)
    top_rules_df.to_csv('top_association_rules.csv', index=False)
    print("✅  Market basket analysis complete. Top rules saved.")
else:
    print("⚠️  No frequent itemsets found. Try lowering min_support.")
# Out:
# ── Top 10 Association Rules (by Lift) ──
#                         antecedents                         consequents  support  confidence   lift
#    (PINK REGENCY TEACUP AND SAUCER)   (GREEN REGENCY TEACUP AND SAUCER)    0.030       0.827 18.070
#   (GREEN REGENCY TEACUP AND SAUCER)    (PINK REGENCY TEACUP AND SAUCER)    0.030       0.666 18.070
#   (GREEN REGENCY TEACUP AND SAUCER)   (ROSES REGENCY TEACUP AND SAUCER)    0.036       0.783 15.091
#   (ROSES REGENCY TEACUP AND SAUCER)   (GREEN REGENCY TEACUP AND SAUCER)    0.036       0.691 15.091
#  (GARDENERS KNEELING PAD KEEP CALM) (GARDENERS KNEELING PAD CUP OF TEA)    0.031       0.612 14.556
# (GARDENERS KNEELING PAD CUP OF TEA)  (GARDENERS KNEELING PAD KEEP CALM)    0.031       0.729 14.556
#        (ALARM CLOCK BAKELIKE GREEN)          (ALARM CLOCK BAKELIKE RED)    0.035       0.672 11.560
#          (ALARM CLOCK BAKELIKE RED)        (ALARM CLOCK BAKELIKE GREEN)    0.035       0.604 11.560
# (WOODEN PICTURE FRAME WHITE FINISH)        (WOODEN FRAME ANTIQUE WHITE)    0.031       0.534  9.942
#        (WOODEN FRAME ANTIQUE WHITE) (WOODEN PICTURE FRAME WHITE FINISH)    0.031       0.577  9.942
# ✅  Market basket analysis complete. Top rules saved.
